# %%
import nltk

# %%
# nltk.download()

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
example_text = 'Hello Mr. Smith, how are you doing today? The weather is great and Python is awesome. The sky is pinkish-blue. You should not eat cardboard.'
print(sent_tokenize(example_text))
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great and Python is awesome.', 'The sky is pinkish-blue.', 'You should not eat cardboard.']

# %%
print(word_tokenize(example_text))
# Out:
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', 'and', 'Python', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', 'not', 'eat', 'cardboard', '.']

# %%
for i in word_tokenize(example_text):
    print(i)
# Out:
# Hello
# Mr.
# Smith
# ,
# how
# are
# you
# doing
# today
# ?
# The
# weather
# is
# great
# and
# Python
# is
# awesome
# .
# The
# sky
# is
# pinkish-blue
# .
# You
# should
# not
# eat
# cardboard
# .

# %%
from nltk.corpus import stopwords

example_sentence = 'This is an example showing off stop word filtration.'
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'can', 'doesn', 'this', 'when', 'now', 'during', 'so', "it's", 'it', 'because', 'did', 'each', 'between', 'these', 'she', 'were', 'very', 'herself', 'over', 'isn', 'into', 'until', 'again', 'do', 'ain', 'myself', 'ours', "weren't", 'that', 've', 'weren', 'themselves', 'about', 'some', 'yourselves', 'nor', "haven't", 'i', 'his', 'same', 'under', 'such', 'against', 'up', 's', 'hasn', "mustn't", 'any', 'aren', "that'll", 'while', "doesn't", "you'd", 'had', 'out', 'as', 'my', 'don', 'for', 'who', "needn't", "wasn't", 'shouldn', 'and', 'having', 'them', 'himself', 'or', 'those', 'what', 'have', "won't", "aren't", "hasn't", 'me', 'been', 'should', 'mightn', 'on', "shouldn't", 're', 'with', 'than', 'yourself', 'their', 'after', 'hadn', 'a', 'where', 'wasn', 'are', 'at', 'ma', 'how', 'm', 'then', 'd', 'why', "she's", 'he', 'am', 'just', "didn't", 'but', 'other', 'the', 'here', 'which', 'before', 'most', 'no', 'haven', 'doing', "you've", 'him', 'in', "you'll", 'does', "mightn't", 'will', 'whom', 'of', 'its', 'if', 'is', 'yours', 'above', 'further', 'll', "hadn't", 'be', 'below', 'won', 'they', 'hers', 'an', 't', 'couldn', 'wouldn', 'was', "don't", 'ourselves', "couldn't", 'has', 'your', 'there', 'not', 'all', 'once', 'few', 'only', "should've", "you're", 'through', 'down', "shan't", 'didn', 'own', 'theirs', 'needn', 'from', 'you', 'being', 'y', 'to', 'too', 'itself', 'we', 'by', 'off', 'mustn', "wouldn't", "isn't", 'o', 'more', 'shan', 'her', 'both', 'our'}

# %%
words = word_tokenize(example_sentence)
filtered_sentence = []
for w in words:
    if w not in stop_words:
        filtered_sentence.append(w)
print(filtered_sentence)
# Out:
# ['This', 'example', 'showing', 'stop', 'word', 'filtration', '.']

# %%
filtered_sentence = [w for w in words if not w in stop_words]
print(filtered_sentence)
# Out:
# ['This', 'example', 'showing', 'stop', 'word', 'filtration', '.']

# %% [markdown]
# ### Video 3

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
ps = PorterStemmer()
example_words = ['python', 'pythoner', 'pythoning', 'pythoned', 'pythonly']

for w in example_words:
    print(ps.stem(w))
# Out:
# python
# python
# python
# python
# pythonli

# %%
new_text = 'It is very important to be pythonly while you are pythoning with python. All pythoners have pythoned poorly at least once.'

words = word_tokenize(new_text)
for w in words:
    print(ps.stem(w))
# Out:
# It
# is
# veri
# import
# to
# be
# pythonli
# while
# you
# are
# python
# with
# python
# .
# all
# python
# have
# python
# poorli
# at
# least
# onc
# .

# %% [markdown]
# ### Video 4

# %%
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

# %%
train_text = state_union.raw('2005-GWBush.txt')
sample_text = state_union.raw('2006-GWBush.txt')

custom_sent_tokenizer = PunktSentenceTokenizer(train_text)
tokenized = custom_sent_tokenizer.tokenize(sample_text)

# print(train_text)

# %%
def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            print(tagged)

    except Exception as e:
        print(str(e))

# %%
# process_content()

# %% [markdown]
# ### Video 5

# %%
def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            
            chunkGram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)
            print(chunked)
            chunked.draw()

    except Exception as e:
        print(str(e))

# %%
# process_content()

# %% [markdown]
# ### Video 6

# %%
def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            
            chunkGram = r"""Chunk: {<.*>+}
                                    }<VB.?|IN|DT|TO>+{"""
            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)
            print(chunked)
            chunked.draw()

    except Exception as e:
        print(str(e))

# %%
# process_content()

# %% [markdown]
# ### Video 7

# %%
def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            
            namedEnt = nltk.ne_chunk(tagged, binary=True)
            namedEnt.draw()
    except Exception as e:
        print(str(e))

# %%
# process_content()

# %% [markdown]
# ### Video 8

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize('cats'))
print(lemmatizer.lemmatize('cacti'))
print(lemmatizer.lemmatize('geese'))
print(lemmatizer.lemmatize('rocks'))
print(lemmatizer.lemmatize('python'))
print(lemmatizer.lemmatize('better', pos='a'))
print(lemmatizer.lemmatize('best', pos='a'))
print(lemmatizer.lemmatize('run'))
print(lemmatizer.lemmatize('run', 'v'))
# Out:
# cat
# cactus
# goose
# rock
# python
# good
# best
# run
# run

# %% [markdown]
# ### Video 9

# %%
print(nltk.__file__)
# Out:
# C:\Users\rodri\anaconda3\lib\site-packages\nltk\__init__.py

# %%
from nltk.corpus import gutenberg
sample = gutenberg.raw('bible-kjv.txt')
tok = sent_tokenize(sample)
print(tok[5:15])
# Out:
# ['1:5 And God called the light Day, and the darkness he called Night.', 'And the evening and the morning were the first day.', '1:6 And God said, Let there be a firmament in the midst of the waters,\nand let it divide the waters from the waters.', '1:7 And God made the firmament, and divided the waters which were\nunder the firmament from the waters which were above the firmament:\nand it was so.', '1:8 And God called the firmament Heaven.', 'And the evening and the\nmorning were the second day.', '1:9 And God said, Let the waters under the heaven be gathered together\nunto one place, and let the dry land appear: and it was so.', '1:10 And God called the dry land Earth; and the gathering together of\nthe waters called he Seas: and God saw that it was good.', '1:11 And God said, Let the earth bring forth grass, the herb yielding\nseed, and the fruit tree yielding fruit after his kind, whose seed is\nin itself, upon the earth: and it was so.', '1:12 And the earth brought forth grass, and herb yielding seed after\nhis kind, and the tree yielding fruit, whose seed was in itself, after\nhis kind: and God saw that it was good.']

# %% [markdown]
# ### Video 10

# %%
from nltk.corpus import wordnet

syns = wordnet.synsets('program')
print(syns[0])
print(syns[0].lemmas()[0].name())
# Out:
# Synset('plan.n.01')
# plan

# %%
print(syns[0].definition())
# Out:
# a series of steps to be carried out or goals to be accomplished

# %%
print(syns[0].examples())
# Out:
# ['they drew up a six-step plan', 'they discussed plans for a new bond issue']

# %%
synonyms = []
antonyms = []

for syn in wordnet.synsets('good'):
    for l in syn.lemmas():
        print('l:',l)
        synonyms.append(l.name())
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())
            
print(set(synonyms))
print(set(antonyms))
# Out:
# l: Lemma('good.n.01.good')
# l: Lemma('good.n.02.good')
# l: Lemma('good.n.02.goodness')
# l: Lemma('good.n.03.good')
# l: Lemma('good.n.03.goodness')
# l: Lemma('commodity.n.01.commodity')
# l: Lemma('commodity.n.01.trade_good')
# l: Lemma('commodity.n.01.good')
# l: Lemma('good.a.01.good')
# l: Lemma('full.s.06.full')
# l: Lemma('full.s.06.good')
# l: Lemma('good.a.03.good')
# l: Lemma('estimable.s.02.estimable')
# l: Lemma('estimable.s.02.good')
# l: Lemma('estimable.s.02.honorable')
# l: Lemma('estimable.s.02.respectable')
# l: Lemma('beneficial.s.01.beneficial')
# l: Lemma('beneficial.s.01.good')
# l: Lemma('good.s.06.good')
# l: Lemma('good.s.07.good')
# l: Lemma('good.s.07.just')
# l: Lemma('good.s.07.upright')
# l: Lemma('adept.s.01.adept')
# l: Lemma('adept.s.01.expert')
# l: Lemma('adept.s.01.good')
# l: Lemma('adept.s.01.practiced')
# l: Lemma('adept.s.01.proficient')
# l: Lemma('adept.s.01.skillful')
# l: Lemma('adept.s.01.skilful')
# l: Lemma('good.s.09.good')
# l: Lemma('dear.s.02.dear')
# l: Lemma('dear.s.02.good')
# l: Lemma('dear.s.02.near')
# l: Lemma('dependable.s.04.dependable')
# l: Lemma('dependable.s.04.good')
# l: Lemma('dependable.s.04.safe')
# l: Lemma('dependable.s.04.secure')
# l: Lemma('good.s.12.good')
# l: Lemma('good.s.12.right')
# l: Lemma('good.s.12.ripe')
# l: Lemma('good.s.13.good')
# l: Lemma('good.s.13.well')
# l: Lemma('effective.s.04.effective')
# l: Lemma('effective.s.04.good')
# l: Lemma('effective.s.04.in_effect')
# l: Lemma('effective.s.04.in_force')
# l: Lemma('good.s.15.good')
# l: Lemma('good.s.16.good')
# l: Lemma('good.s.16.serious')
# l: Lemma('good.s.17.good')
# l: Lemma('good.s.17.sound')
# l: Lemma('good.s.18.good')
# l: Lemma('good.s.18.salutary')
# l: Lemma('good.s.19.good')
# l: Lemma('good.s.19.honest')
# l: Lemma('good.s.20.good')
# l: Lemma('good.s.20.undecomposed')
# l: Lemma('good.s.20.unspoiled')
# l: Lemma('good.s.20.unspoilt')
# l: Lemma('good.s.21.good')
# l: Lemma('well.r.01.well')
# l: Lemma('well.r.01.good')
# l: Lemma('thoroughly.r.02.thoroughly')
# l: Lemma('thoroughly.r.02.soundly')
# l: Lemma('thoroughly.r.02.good')
# {'dear', 'in_force', 'commodity', 'beneficial', 'adept', 'well', 'ripe', 'sound', 'full', 'goodness', 'soundly', 'respectable', 'proficient', 'safe', 'unspoilt', 'just', 'honest', 'upright', 'skilful', 'dependable', 'undecomposed', 'honorable', 'expert', 'right', 'effective', 'thoroughly', 'in_effect', 'near', 'trade_good', 'unspoiled', 'good', 'practiced', 'secure', 'skillful', 'salutary', 'serious', 'estimable'}
# {'evil', 'badness', 'evilness', 'bad', 'ill'}

# %%
w1 = wordnet.synset('ship.n.01')
w2 = wordnet.synset('boat.n.01')

print(w1.wup_similarity(w2))
# Out:
# 0.9090909090909091

# %%
w1 = wordnet.synset('ship.n.01')
w2 = wordnet.synset('car.n.01')

print(w1.wup_similarity(w2))
# Out:
# 0.6956521739130435

# %%
w1 = wordnet.synset('ship.n.01')
w2 = wordnet.synset('cat.n.01')

print(w1.wup_similarity(w2))
# Out:
# 0.32

# %% [markdown]
# ### Video 11

# %%
import random
from nltk.corpus import movie_reviews

# %%
documents = [(list(movie_reviews.words(fileid)), category) 
             for category in movie_reviews.categories() 
             for fileid in movie_reviews.fileids(category)]

random.shuffle(documents)

# %%
# print(documents[1])

# %%
all_words = []

for w in movie_reviews.words():
    all_words.append(w.lower())

# %%
all_words = nltk.FreqDist(all_words)

print(all_words.most_common(15))
print(all_words['stupid'])
# Out:
# [(',', 77717), ('the', 76529), ('.', 65876), ('a', 38106), ('and', 35576), ('of', 34123), ('to', 31937), ("'", 30585), ('is', 25195), ('in', 21822), ('s', 18513), ('"', 17612), ('it', 16107), ('that', 15924), ('-', 15595)]
# 253

# %% [markdown]
# ### Video 12

# %%
word_features = list(all_words.keys())[:3000]

def find_features(document):
    words = set(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)
    return features

print(find_features(movie_reviews.words('neg/cv000_29416.txt')))
# Out:
# {'plot': True, ':': True, 'two': True, 'teen': True, 'couples': True, 'go': True, 'to': True, 'a': True, 'church': True, 'party': True, ',': True, 'drink': True, 'and': True, 'then': True, 'drive': True, '.': True, 'they': True, 'get': True, 'into': True, 'an': True, 'accident': True, 'one': True, 'of': True, 'the': True, 'guys': True, 'dies': True, 'but': True, 'his': True, 'girlfriend': True, 'continues': True, 'see': True, 'him': True, 'in': True, 'her': True, 'life': True, 'has': True, 'nightmares': True, 'what': True, "'": True, 's': True, 'deal': True, '?': True, 'watch': True, 'movie': True, '"': True, 'sorta': True, 'find': True, 'out': True, 'critique': True, 'mind': True, '-': True, 'fuck': True, 'for': True, 'generation': True, 'that': True, 'touches': True, 'on': True, 'very': True, 'cool': True, 'idea': True, 'presents': True, 'it': True, 'bad': True, 'package': True, 'which': True, 'is': True, 'makes': True, 'this': True, 'review': True, 'even': True, 'harder': True, 'write': True, 'since': True, 'i': True, 'generally': True, 'applaud': True, 'films': True, 'attempt': True, 'break': True, 'mold': True, 'mess': True, 'with': True, 'your': True, 'head': True, 'such': True, '(': True, 'lost': True, 'highway': True, '&': True, 'memento': True, ')': True, 'there': True, 'are': True, 'good': True, 'ways': True, 'making': True, 'all': True, 'types': True, 'these': True, 'folks': True, 'just': True, 'didn': True, 't': True, 'snag': True, 'correctly': True, 'seem': True, 'have': True, 'taken': True, 'pretty': True, 'neat': True, 'concept': True, 'executed': True, 'terribly': True, 'so': True, 'problems': True, 'well': True, 'its': True, 'main': True, 'problem': True, 'simply': True, 'too': True, 'jumbled': True, 'starts': True, 'off': True, 'normal': True, 'downshifts': True, 'fantasy': True, 'world': True, 'you': True, 'as': True, 'audience': True, 'member': True, 'no': True, 'going': True, 'dreams': True, 'characters': True, 'coming': True, 'back': True, 'from': True, 'dead': True, 'others': True, 'who': True, 'look': True, 'like': True, 'strange': True, 'apparitions': True, 'disappearances': True, 'looooot': True, 'chase': True, 'scenes': True, 'tons': True, 'weird': True, 'things': True, 'happen': True, 'most': True, 'not': True, 'explained': True, 'now': True, 'personally': True, 'don': True, 'trying': True, 'unravel': True, 'film': True, 'every': True, 'when': True, 'does': True, 'give': True, 'me': True, 'same': True, 'clue': True, 'over': True, 'again': True, 'kind': True, 'fed': True, 'up': True, 'after': True, 'while': True, 'biggest': True, 'obviously': True, 'got': True, 'big': True, 'secret': True, 'hide': True, 'seems': True, 'want': True, 'completely': True, 'until': True, 'final': True, 'five': True, 'minutes': True, 'do': True, 'make': True, 'entertaining': True, 'thrilling': True, 'or': True, 'engaging': True, 'meantime': True, 'really': True, 'sad': True, 'part': True, 'arrow': True, 'both': True, 'dig': True, 'flicks': True, 'we': True, 'actually': True, 'figured': True, 'by': True, 'half': True, 'way': True, 'point': True, 'strangeness': True, 'did': True, 'start': True, 'little': True, 'bit': True, 'sense': True, 'still': True, 'more': True, 'guess': True, 'bottom': True, 'line': True, 'movies': True, 'should': True, 'always': True, 'sure': True, 'before': True, 'given': True, 'password': True, 'enter': True, 'understanding': True, 'mean': True, 'showing': True, 'melissa': True, 'sagemiller': True, 'running': True, 'away': True, 'visions': True, 'about': True, '20': True, 'throughout': True, 'plain': True, 'lazy': True, '!': True, 'okay': True, 'people': True, 'chasing': True, 'know': True, 'need': True, 'how': True, 'giving': True, 'us': True, 'different': True, 'offering': True, 'further': True, 'insight': True, 'down': True, 'apparently': True, 'studio': True, 'took': True, 'director': True, 'chopped': True, 'themselves': True, 'shows': True, 'might': True, 've': True, 'been': True, 'decent': True ...

# %%
feature_sets = [(find_features(rev), category) for (rev, category) in documents]
# feature_sets -- Truena si lo imprimes haha

# %% [markdown]
# ### Video 13

# %%
training_set = feature_sets[:1900]
testing_set = feature_sets[1900:]

classifier = nltk.NaiveBayesClassifier.train(training_set)
print("Naive Bayes Algo accuracy percent:", {nltk.classify.accuracy(classifier, testing_set)*100})
classifier.show_most_informative_features(15)
# Out:
# Naive Bayes Algo accuracy percent: {81.0}
# Most Informative Features
#                    sucks = True              neg : pos    =     10.5 : 1.0
#                  frances = True              pos : neg    =      9.1 : 1.0
#            unimaginative = True              neg : pos    =      8.3 : 1.0
#                  martian = True              neg : pos    =      7.6 : 1.0
#                  idiotic = True              neg : pos    =      7.2 : 1.0
#                   regard = True              pos : neg    =      7.1 : 1.0
#                atrocious = True              neg : pos    =      6.9 : 1.0
#                   kombat = True              neg : pos    =      6.9 : 1.0
#               schumacher = True              neg : pos    =      6.9 : 1.0
#              silverstone = True              neg : pos    =      6.9 : 1.0
#                 obstacle = True              pos : neg    =      6.4 : 1.0
#                    kudos = True              pos : neg    =      6.3 : 1.0
#                  miscast = True              neg : pos    =      6.1 : 1.0
#                   turkey = True              neg : pos    =      6.1 : 1.0
#                 explores = True              pos : neg    =      5.9 : 1.0

# %% [markdown]
# ### Video 14

# %%
import pickle

# %%
save_classifier = open('naivebayes.pickle', 'wb')
pickle.dump(classifier, save_classifier)
save_classifier.close()

# %%
classifier_f = open('naivebayes.pickle', 'rb')
classifier = pickle.load(classifier_f)
classifier_f.close()

# %%
print("Naive Bayes Algo accuracy percent:", {nltk.classify.accuracy(classifier, testing_set)*100})
classifier.show_most_informative_features(15)
# Out:
# Naive Bayes Algo accuracy percent: {81.0}
# Most Informative Features
#                    sucks = True              neg : pos    =     10.5 : 1.0
#                  frances = True              pos : neg    =      9.1 : 1.0
#            unimaginative = True              neg : pos    =      8.3 : 1.0
#                  martian = True              neg : pos    =      7.6 : 1.0
#                  idiotic = True              neg : pos    =      7.2 : 1.0
#                   regard = True              pos : neg    =      7.1 : 1.0
#                atrocious = True              neg : pos    =      6.9 : 1.0
#                   kombat = True              neg : pos    =      6.9 : 1.0
#               schumacher = True              neg : pos    =      6.9 : 1.0
#              silverstone = True              neg : pos    =      6.9 : 1.0
#                 obstacle = True              pos : neg    =      6.4 : 1.0
#                    kudos = True              pos : neg    =      6.3 : 1.0
#                  miscast = True              neg : pos    =      6.1 : 1.0
#                   turkey = True              neg : pos    =      6.1 : 1.0
#                 explores = True              pos : neg    =      5.9 : 1.0

# %% [markdown]
# ### Video 15

# %%
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC

# %%
MNB_classifier = SklearnClassifier(MultinomialNB())
MNB_classifier.train(training_set)

print("MNB classifier accuracy percent:", {nltk.classify.accuracy(MNB_classifier, testing_set)*100})
# Out:
# MNB classifier accuracy percent: {83.0}

# %%
#GaussianNB_classifier = SklearnClassifier(GaussianNB())
#GaussianNB_classifier.train(training_set)

#print("GaussianNB classifier accuracy percent:", {nltk.classify.accuracy(GaussianNB_classifier, testing_set)*100})

# %%
BernoulliNB_classifier = SklearnClassifier(BernoulliNB())
BernoulliNB_classifier.train(training_set)

print("BernoulliNB classifier accuracy percent:", {nltk.classify.accuracy(BernoulliNB_classifier, testing_set)*100})
# Out:
# BernoulliNB classifier accuracy percent: {81.0}

# %%
LogisticRegression_classifier = SklearnClassifier(LogisticRegression())
LogisticRegression_classifier.train(training_set)

print("LogisticRegression classifier accuracy percent:", {nltk.classify.accuracy(LogisticRegression_classifier, testing_set)*100})
# Out:
# LogisticRegression classifier accuracy percent: {86.0}
# C:\Users\rodri\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
SGD_classifier = SklearnClassifier(SGDClassifier())
SGD_classifier.train(training_set)

print("SGD classifier accuracy percent:", {nltk.classify.accuracy(SGD_classifier, testing_set)*100})
# Out:
# SGD classifier accuracy percent: {88.0}

# %%
SVC_classifier = SklearnClassifier(SVC())
SVC_classifier.train(training_set)

print("SVC classifier accuracy percent:", {nltk.classify.accuracy(SVC_classifier, testing_set)*100})
# Out:
# SVC classifier accuracy percent: {83.0}

# %%
LinearSVC_classifier = SklearnClassifier(LinearSVC())
LinearSVC_classifier.train(training_set)

print("LinearSVC classifier accuracy percent:", {nltk.classify.accuracy(LinearSVC_classifier, testing_set)*100})
# Out:
# LinearSVC classifier accuracy percent: {84.0}

# %%
NuSVC_classifier = SklearnClassifier(NuSVC())
NuSVC_classifier.train(training_set)

print("NuSVC classifier accuracy percent:", {nltk.classify.accuracy(NuSVC_classifier, testing_set)*100})
# Out:
# NuSVC classifier accuracy percent: {84.0}

# %% [markdown]
# ### Video 16

# %%
from nltk.classify import ClassifierI
from statistics import mode

# %%
class VoteClassifier(ClassifierI):
    def __init__(self, *classifiers):
        self._classifiers = classifiers
        
    def classify(self, features):
        votes = []
        
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)
        
        return mode(votes)
    
    def confidence(self, features):
        votes = []
        
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)
            
        choice_votes = votes.count(mode(votes))
        conf = choice_votes / len(votes)
        
        return conf

# %%
voted_classifier = VoteClassifier(classifier, MNB_classifier, BernoulliNB_classifier, 
                                  LogisticRegression_classifier, SGD_classifier, LinearSVC_classifier, 
                                  NuSVC_classifier)

print("Voted classifier accuracy percent:", {nltk.classify.accuracy(voted_classifier, testing_set)*100})

for i in range(5):
    print("Classification:", {voted_classifier.classify(testing_set[i][0])}, "Confidence %:", {voted_classifier.confidence(testing_set[i][0]) * 100})
# Out:
# Voted classifier accuracy percent: {86.0}
# Classification: {'neg'} Confidence %: {100.0}
# Classification: {'neg'} Confidence %: {100.0}
# Classification: {'pos'} Confidence %: {57.14285714285714}
# Classification: {'pos'} Confidence %: {100.0}
# Classification: {'pos'} Confidence %: {100.0}

# %% [markdown]
# ### Video 17

# %%
# negative
training_set = feature_sets[100:]
testing_set = feature_sets[:100]

classifier = nltk.NaiveBayesClassifier.train(training_set)
print("Naive Bayes Algo accuracy percent:", {nltk.classify.accuracy(classifier, testing_set)*100})
classifier.show_most_informative_features(15)
# Out:
# Naive Bayes Algo accuracy percent: {79.0}
# Most Informative Features
#                   regard = True              pos : neg    =     11.1 : 1.0
#                atrocious = True              neg : pos    =     10.9 : 1.0
#                    sucks = True              neg : pos    =     10.1 : 1.0
#                   annual = True              pos : neg    =      9.8 : 1.0
#                  frances = True              pos : neg    =      9.1 : 1.0
#                   stinks = True              neg : pos    =      8.9 : 1.0
#            unimaginative = True              neg : pos    =      8.2 : 1.0
#              silverstone = True              neg : pos    =      7.6 : 1.0
#                  idiotic = True              neg : pos    =      7.1 : 1.0
#                     mena = True              neg : pos    =      6.9 : 1.0
#                   shoddy = True              neg : pos    =      6.9 : 1.0
#                   suvari = True              neg : pos    =      6.9 : 1.0
#                   turkey = True              neg : pos    =      6.7 : 1.0
#               schumacher = True              neg : pos    =      6.5 : 1.0
#                 obstacle = True              pos : neg    =      6.4 : 1.0

# %%
MNB_classifier.train(training_set)
print("MNB classifier accuracy percent:", {nltk.classify.accuracy(MNB_classifier, testing_set)*100})

BernoulliNB_classifier.train(training_set)
print("BernoulliNB classifier accuracy percent:", {nltk.classify.accuracy(BernoulliNB_classifier, testing_set)*100})

LogisticRegression_classifier.train(training_set)
print("LogisticRegression classifier accuracy percent:", {nltk.classify.accuracy(LogisticRegression_classifier, testing_set)*100})

SGD_classifier.train(training_set)
print("SGD classifier accuracy percent:", {nltk.classify.accuracy(SGD_classifier, testing_set)*100})

SVC_classifier.train(training_set)
print("SVC classifier accuracy percent:", {nltk.classify.accuracy(SVC_classifier, testing_set)*100})

LinearSVC_classifier.train(training_set)
print("LinearSVC classifier accuracy percent:", {nltk.classify.accuracy(LinearSVC_classifier, testing_set)*100})

NuSVC_classifier.train(training_set)
print("NuSVC classifier accuracy percent:", {nltk.classify.accuracy(NuSVC_classifier, testing_set)*100})
# Out:
# MNB classifier accuracy percent: {80.0}
# BernoulliNB classifier accuracy percent: {79.0}
# C:\Users\rodri\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression classifier accuracy percent: {81.0}
# SGD classifier accuracy percent: {77.0}
# SVC classifier accuracy percent: {83.0}
# LinearSVC classifier accuracy percent: {79.0}
# NuSVC classifier accuracy percent: {83.0}

# %% [markdown]
# ### Video 18

# %%
import nltk
import random
#from nltk.corpus import movie_reviews
from nltk.classify.scikitlearn import SklearnClassifier
import pickle
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from nltk.classify import ClassifierI
from statistics import mode
from nltk.tokenize import word_tokenize



class VoteClassifier(ClassifierI):
    def __init__(self, *classifiers):
        self._classifiers = classifiers

    def classify(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)
        return mode(votes)

    def confidence(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)

        choice_votes = votes.count(mode(votes))
        conf = choice_votes / len(votes)
        return conf
    
short_pos = open("positive.txt","r").read()
short_neg = open("negative.txt","r").read()

# move this up here
all_words = []
documents = []


#  j is adject, r is adverb, and v is verb
#allowed_word_types = ["J","R","V"]
allowed_word_types = ["J"]

for p in short_pos.split('\n'):
    documents.append( (p, "pos") )
    words = word_tokenize(p)
    pos = nltk.pos_tag(words)
    for w in pos:
        if w[1][0] in allowed_word_types:
            all_words.append(w[0].lower())

    
for p in short_neg.split('\n'):
    documents.append( (p, "neg") )
    words = word_tokenize(p)
    pos = nltk.pos_tag(words)
    for w in pos:
        if w[1][0] in allowed_word_types:
            all_words.append(w[0].lower())



save_documents = open("pickled_algos/documents.pickle","wb")
pickle.dump(documents, save_documents)
save_documents.close()


all_words = nltk.FreqDist(all_words)


word_features = list(all_words.keys())[:5000]


save_word_features = open("pickled_algos/word_features5k.pickle","wb")
pickle.dump(word_features, save_word_features)
save_word_features.close()


def find_features(document):
    words = word_tokenize(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features

featuresets = [(find_features(rev), category) for (rev, category) in documents]

random.shuffle(featuresets)

save_features = open("pickled_algos/featuresets.pickle","wb")
pickle.dump(featuresets, save_features)
save_features.close()

print(len(featuresets))

testing_set = featuresets[10000:]
training_set = featuresets[:10000]


classifier = nltk.NaiveBayesClassifier.train(training_set)
print("Original Naive Bayes Algo accuracy percent:", (nltk.classify.accuracy(classifier, testing_set))*100)
classifier.show_most_informative_features(15)

###############
save_classifier = open("pickled_algos/originalnaivebayes5k.pickle","wb")
pickle.dump(classifier, save_classifier)
save_classifier.close()

MNB_classifier = SklearnClassifier(MultinomialNB())
MNB_classifier.train(training_set)
print("MNB_classifier accuracy percent:", (nltk.classify.accuracy(MNB_classifier, testing_set))*100)

save_classifier = open("pickled_algos/MNB_classifier5k.pickle","wb")
pickle.dump(MNB_classifier, save_classifier)
save_classifier.close()

BernoulliNB_classifier = SklearnClassifier(BernoulliNB())
BernoulliNB_classifier.train(training_set)
print("BernoulliNB_classifier accuracy percent:", (nltk.classify.accuracy(BernoulliNB_classifier, testing_set))*100)

save_classifier = open("pickled_algos/BernoulliNB_classifier5k.pickle","wb")
pickle.dump(BernoulliNB_classifier, save_classifier)
save_classifier.close()

LogisticRegression_classifier = SklearnClassifier(LogisticRegression())
LogisticRegression_classifier.train(training_set)
print("LogisticRegression_classifier accuracy percent:", (nltk.classify.accuracy(LogisticRegression_classifier, testing_set))*100)

save_classifier = open("pickled_algos/LogisticRegression_classifier5k.pickle","wb")
pickle.dump(LogisticRegression_classifier, save_classifier)
save_classifier.close()


LinearSVC_classifier = SklearnClassifier(LinearSVC())
LinearSVC_classifier.train(training_set)
print("LinearSVC_classifier accuracy percent:", (nltk.classify.accuracy(LinearSVC_classifier, testing_set))*100)

save_classifier = open("pickled_algos/LinearSVC_classifier5k.pickle","wb")
pickle.dump(LinearSVC_classifier, save_classifier)
save_classifier.close()


##NuSVC_classifier = SklearnClassifier(NuSVC())
##NuSVC_classifier.train(training_set)
##print("NuSVC_classifier accuracy percent:", (nltk.classify.accuracy(NuSVC_classifier, testing_set))*100)


SGDC_classifier = SklearnClassifier(SGDClassifier())
SGDC_classifier.train(training_set)
print("SGDClassifier accuracy percent:",nltk.classify.accuracy(SGDC_classifier, testing_set)*100)

save_classifier = open("pickled_algos/SGDC_classifier5k.pickle","wb")
pickle.dump(SGDC_classifier, save_classifier)
save_classifier.close()
# Out:
# 10664
# Original Naive Bayes Algo accuracy percent: 69.42771084337349
# Most Informative Features
#               engrossing = True              pos : neg    =     21.8 : 1.0
#                wonderful = True              pos : neg    =     19.8 : 1.0
#                  generic = True              neg : pos    =     16.3 : 1.0
#                  routine = True              neg : pos    =     14.9 : 1.0
#               refreshing = True              pos : neg    =     14.4 : 1.0
#                   boring = True              neg : pos    =     13.8 : 1.0
#                inventive = True              pos : neg    =     13.7 : 1.0
#                     flat = True              neg : pos    =     13.3 : 1.0
#                 powerful = True              pos : neg    =     12.5 : 1.0
#                     warm = True              pos : neg    =     12.3 : 1.0
#                realistic = True              pos : neg    =     11.7 : 1.0
#                   stupid = True              neg : pos    =     11.3 : 1.0
#                 mindless = True              neg : pos    =     11.0 : 1.0
#                 tiresome = True              neg : pos    =     10.3 : 1.0
#                     dull = True              neg : pos    =     10.0 : 1.0
# MNB_classifier accuracy percent: 70.48192771084338
# BernoulliNB_classifier accuracy percent: 69.7289156626506
# LogisticRegression_classifier accuracy percent: 70.03012048192771
# LinearSVC_classifier accuracy percent: 67.01807228915662
# SGDClassifier accuracy percent: 69.7289156626506

# %% [markdown]
# ### Video 19

# %%
import sentiment_mod as s

print(s.sentiment("This movie was awesome! The acting was great, plot was wonderful, and there were pythons...so yea!"))
print(s.sentiment("This movie was utter junk. There were absolutely 0 pythons. I don't see what the point was at all. Horrible movie, 0/10"))
# Out:
# 10664
# ('pos', 1.0)
# ('neg', 1.0)

# %% [markdown]
# ### Video 20

# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import time
import json

from config import ckey, csecret, atoken, asecret

search_words = ['happy']

class listener(StreamListener):

    def on_data(self, data):
        try:
            all_data = json.loads(data)
        except:
            return True

        tweet = all_data["text"]
        print(s.sentiment(tweet))
        sentiment_value, confidence = s.sentiment(tweet)
        print(tweet, sentiment_value, confidence)
        
        if confidence >= 0.8:
            with open('twitter-out.txt', 'a') as output:
                output.write(sentiment_value)
                output.write('\n')      

        return True

    def on_error(self, status):
        print(status)

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

twitterStream = Stream(auth, listener())
twitterStream.filter(track=search_words)
# Out:
# ('neg', 1.0)
# RT @kaeyasdick: as a feminist i’m very happy the genshin boobs don’t jiggle anymore but as a bisexua- neg 1.0
# ('neg', 1.0)
# Happy bday @playapex stonks. https://t.co/uyEH3jREKJ neg 1.0
# ('pos', 1.0)
# RT @anaake_art: #HappyBirthdayApex 💕 I'm so happy to be part of this community 🥺 https://t.co/lOzRPSdnGh pos 1.0
# ('pos', 1.0)
# RT @moneyymaya: I *really* love seeing black girls do cosplay it makes my heart so happy pos 1.0
# ('neg', 1.0)
# RT @megumi_3587: エマ・ヴェルデちゃんHappy Birthday！
# #エマ・ヴェルデ生誕祭2021
# #エマ・ヴェルデ誕生祭2021
# #2月5日はエマ・ヴェルデの誕生日
# #虹ヶ咲学園スクールアイドル同好会
# #ラブライバーと繋がりたい
#
# ↓↓↓ラブライバーの… neg 1.0
# ('pos', 1.0)
# Happy birthday Taehyun!! 🎈 Hope you're so happy today and always. I admire you so much, I've learned lots thanks to… https://t.co/nIDRiMq3EZ pos 1.0
# ('pos', 1.0)
# RT @wolv_uchiha: @lovinmygirls218 @CartuneNetwerk Hate to break it to you but a large part of keeping our woman happy is suffering in silen… pos 1.0
# ('neg', 1.0)
# RT @DONT_PANIC22: Of the mountains I have climbed
# Traveled between space and time
# Tell them my story my struggles and my glory
# Don't leave… neg 1.0
# ('pos', 1.0)
# ya termine true beauty a
# solo quiero decir que si me gusto and im happy for seojun debut😭😭😭😭😭 pos 1.0
# ('pos', 1.0)
# RT @originalree_: purrrrr 😝 happy birthday fren ♥️ pos 1.0
# ('pos', 0.6)
# RT @martinzambada: Hermosa 😍😍 ya la sigen activa en #Monterrey pos 0.6
# ('pos', 1.0)
# 🌈Have a nice day🌈
#
# #rainbow
# #happy
# #suncatcher https://t.co/DzBAVbMK1p pos 1.0
# ('pos', 0.6)
# Kue kodok spesyel nya di makan ya, @taehyvnkng Tejo! Itu kadonya spesyel aku carinya, kul! Jadi harus di pakai bare… https://t.co/MxVpjzzU7n pos 0.6
# ('pos', 0.8)
# RT @audsldn: Happy birthday to my baby love you so much @neymarjr 💕💕💕💕💕💕💕💕💕💕💕💕💕💕💕 my fav https://t.co/0RxuVhKbxd pos 0.8
# ('pos', 0.8)
# RT @krissingtoIndia: With love and pride today and always,”
# “Prayers and blessings for your graduation and for your future.”
# #SingtoPrachay… pos 0.8
# ('neg', 1.0)
# RT @SakataLex: Happy birthday to the self proclaimed princess who is fantastic at everything she touches, Matsuri! This green haired beauty… neg 1.0
# ('pos', 0.8)
# @DrJoVGM EZ “they’re a little sh*t but I love them and will PROTECC with my life”. And I think good vg music is one… https://t.co/G6CTS9RmMs pos 0.8
# ('pos', 1.0)
# Happy birthday to the greatest 🐐, Cristiano Ronaldo. https://t.co/FAsvJAZY2q pos 1.0
# ('pos', 0.8)
# RT @elytraheart: tommy is such an incredible person even if he tries not to act like it on stream, he knows wilbur has been having a hard t… pos 0.8
# ('pos', 1.0)
# @njchaxx Wiiihhh, happy birthday kamuuu🤩🎉🎁🎈🎂🎊🕯️ bahagia selalu yaaaaa!!!!💖 pos 1.0
# ('neg', 1.0)
# RT @raikumakoto: ゼオンが来島してくれました〜！
# 嬉しい〜〜〜！！
# 多分フランスの方。
# 2枚目でゼオンが泣いてるのは、私の仕事場にゼオンの絵がなかったからかな？ゴメンネ。 neg 1.0
# ('pos', 1.0)
# @GRACEYmusic_ in late but i just wanted to say you’re an incredible human, so talented and kind, i love you and i’m… https://t.co/po6odpZSw1 pos 1.0
# ('pos', 1.0)
# RT @KALIUCHIS: happy anniversary to my first EP,
# Por Vida 🍰 https://t.co/EI36MeyI0r pos 1.0
# ('pos', 1.0)
# happy 100!!!! heheh let's interact juseyooooo 💞 pos 1.0
# ('neg', 1.0)
# @Vinardi_Ethan Sorry to hear your pair didn't arrive the way you expect! Feel free to DM us your order number, and… https://t.co/0BXicsImMl neg 1.0
# ('pos', 0.8)
# RT @FallonTonight: “But if I lost everything that I’ve created because of being myself and because of loving who I want to love, I don’t wa… pos 0.8
# ('pos', 1.0)
# @mworklyy don't skip ur breakfast and have a nice day! be happy ya lip! &lt;3 pos 1.0
# ('pos', 1.0)
# @shukrani I’m proud to say I’ve been playing since the beginning. Happy anniversary apex and all it’s players , eve… https://t.co/T8fEGpxBBG pos 1.0
# ('pos', 0.6)
# Happy early birthday to meeee https://t.co/O6GMFG7UmB pos 0.6
# ('pos', 1.0)
# RT @nakoIoops: happy happy birthday to our angel minju!! &lt;3 thank you for always doing your best and loving izone and wizone ♡♡♡ we love yo… pos 1.0
# ('neg', 1.0)
# I couldn't do anything for the anniversary so I'm sorry &gt;&lt;
#
# Happy 12th Anniversary neg 1.0
# ('pos', 1.0)
# @starrieshi Jangan lupa sarapan, have a nice day and be happy! pos 1.0
# ('neg', 1.0)
# guys i’m so happy, i feel like i’ve reached a high in my life and i hope it lasts a while /pos neg 1.0
# ('neg', 0.6)
# RT @BigRed_STL: Happy birthday to former Big Red DT Mark Duda who was a 4th round pick out of @TerpsFootball in 1983.
#
# Duda played 5 seaso… neg 0.6
# ('neg', 1.0)
# RT @sunterra1014: Happy Birthday Nicolle Wallace.
# @NicolleDWallace neg 1.0
# ('pos', 1.0)
# RT @NfwaOfficial: Here is the official CDP to celebrate NeymarJr 29th Birthday
# •
# Happy Birthday @neymarjr
# •
# Design:- @prolificdesign5
# •
# @n… pos 1.0
# ('pos', 1.0)
# RT @KALIUCHIS: happy anniversary to my first EP,
# Por Vida 🍰 https://t.co/EI36MeyI0r pos 1.0
# ('neg', 1.0)
# Love you more cuzzo!! 🥺💞 neg 1.0
# ('neg', 1.0)
# RT @YGA_GLOBAL: Happy Graduation to #TREASURE's Bang Yedam 👏🎓
#
# @treasuremembers @ygtreasuremaker
# https://t.co/j4MIeWk6FI https://t.co/XYCi… neg 1.0
# ('pos', 0.8)
# RT @vincentiustef: #VincentMasak
# Simple Ramyeon Ala Vincent 🍜
#
# 'Udah lama Vincent ga masak kali ini dengan format berbeda, masak yang simpl… pos 0.8
# ('neg', 1.0)
# RT @TXT_bighit: [#태현생일_txt]
# 🐿HAPPY BIRTHDAY🐿
# 2월 5일
# 오늘은 태현데이!!!
#
# #혼자_있으면_큰 #호박이형아 #달빛정령 #잔디
# #투모로우바이투게더 #TOMORROW_X_TOGETHER #TXT https://t.c… neg 1.0
# ('pos', 1.0)
# @resili6nce happy birthday po pos 1.0
# ('pos', 0.6)
# RT @prettyjoyul: Happy Birthday to our angel, Minju who is so precious and kindhearted thank you for always working hard and even though it… pos 0.6
# ('pos', 1.0)
# Happy birthday 🥳❤️ @ppnaravit
#
# #ppnaravit https://t.co/pBFmwkJ6ye pos 1.0
# ('neg', 1.0)
# RT @SenFeinstein: Happy 108th birthday to Rosa Parks! Her courage and conviction helped make the United States a better place and we foreve… neg 1.0
# ('neg', 1.0)
# @osnonam @lovelyminyoonie @BTS_twt This is so cute and the stickers omg! Thank you for this GA! 😭
#
# Hobi Happy Birt… https://t.co/1XBhko8l73 neg 1.0
# ('neg', 1.0)
# RT @chaenpics: 🤍happy minju day🤍
#
# #민주로_물든지금_영원해 #AngelicMinjuDay https://t.co/QGKAH3sxch neg 1.0
# ('neg', 1.0)
# RT @chococjun: @LiamMcEwan @TXT_members Thankyou 😍💕
# HAPPY TAEHYUN DAY
# #따뜻한_태현이의_스무번째_푸른봄
# #OurGoldenBoyTaehyun
# #TaehyunOurShiningStar
# @TXT_… neg 1.0
# ('neg', 1.0)
# @NicolleDWallace Happy Birthday to you!  Cheers to many more!  Thank you for sharing your gift with us ❤️ neg 1.0
# ('pos', 0.6)
# RT @ateezhobi: our main focus for this cb should definitely be digitals; more longevity on charts &amp; acting smart with the tracking times
#
# i… pos 0.6
# ('neg', 1.0)
# HAPPY BIRTHDAY PARK JISUNG♡︎
#
# #HappyJisungDay
# #StarOfStageJisungDay
# #스무살의_지성이가_그려낼_청춘무비
# #JISUNG #NCT지성
# @NCTsmtown_DREAM neg 1.0
# ('pos', 1.0)
# @lamkyan @TXT_members @TXT_bighit happy birthday taehyun! Yann this is so cutee!! 🥺❤️💕✨
#
# #따뜻한_태현이의_스무번째_푸른봄… https://t.co/Oly2Lzv0rV pos 1.0
# ('pos', 1.0)
# RT @Hii_frennn: Y'all ever get scared to get too happy, cause everytime you do some shit go bad😭? pos 1.0
# ('pos', 1.0)
# RT @JAECSUNG: #JISUNG : this user is saying happy birthday to the loml!! you grew up so well baby and im so proud of you♡ stay healthy and… pos 1.0
# ('pos', 1.0)
# Happy birthday @JessicaLBYRD! Thank you for loving us the way you do. pos 1.0
# ('neg', 0.8)
# RT @alwaysjaehyuk: 🥺: We don’t have time so i’m just gonna say it quickly - you’re so nice and handsome and cute and you sing well and danc… neg 0.8
# ('pos', 1.0)
# RT @bIindeye: jojo siwa talking about her girlfriend has me crying happy tears 🥺  https://t.co/CxiCFFSG4S pos 1.0
# ('neg', 1.0)
# RT @fayren: Happy Birthday Apex Legends 🎂 #HappyBirthdayApex
# This game has been a comfort, ignited passions, creativity, and friendships fo… neg 1.0
# ('neg', 1.0)
# RT @dongminori: SUHO JUGYEONG ENDGAME, INDEED A HAPPY ENDING 😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭
#
# #차은우 #TrueBeauty #TrueBeautyEp16 https://t.co/O1rFX17306 neg 1.0
# ('neg', 1.0)
# RT @shukrani: ❤️ #PlayApex neg 1.0
# ('neg', 1.0)
# RT @NCTsmtown: 🎂HAPPY BIRTHDAY TO #JISUNG
# WE💚YOU
#
# #HAPPYJISUNGDAY #지성
# #NCT #NCTDREAM https://t.co/oRsfGs680F neg 1.0
# ('neg', 1.0)
# RT @smrookies: HAPPY BIRTHDAY TO #JISUNG ♡♡♡ #에스엠루키즈 #지성 #SMROOKIES #SR16B #SMROOKIESENTERTAINMENT https://t.co/WUGgDdaQc1 neg 1.0
# ('pos', 1.0)
# RT @LiamMcEwan: @TXT_members Happy birthday, Taehyun! 🥳 pos 1.0
# ('pos', 1.0)
# RT @khilanii: if 1 nigga making you happy imagine having 10
#
# - Whitney Houston pos 1.0
# ('pos', 1.0)
# RT @DrJimmyStar: Happy #jimmystarshowwithronrussell day ...tune into @w4cyradio from 12-2 pm PT for a great show https://t.co/z64hy02yY2 pos 1.0
# ('pos', 0.8)
# RT @culture2010s: pov: the year was 2010 and you were genuinely happy but didn't know it https://t.co/FmIcfUxhPi pos 0.8
# ('pos', 1.0)
# RT @picshyewon: happy birthday to our multitalented minju angel 🦊🤍 you've worked so hard this past year, juggling idol work and your new mc… pos 1.0
# ('neg', 1.0)
# @luvruhoon HAPPY BIRTHDAY 🎉🎉🎉 neg 1.0
# ('neg', 0.8)
# RT @omycutieboi: #RT HAPPY JISUNG DAY 𓂃 𓈒𓏸 ♡
# 알티 추첨을 통해 총 세분께
# 지성 틴케이스를 보내드립니다
# * 추후 디자인 수정 될 수 있음
# * 국내 거주자 한정
#
# #HAPPYJISUNGDAY
# #스무살의_지성이가_그… neg 0.8
# ('pos', 0.8)
# RT @FabrizioRomano: Neymar here ‘preparing’ the announcement for his new contract agreed and set to be signed with #PSG. 🇧🇷
#
# He’s so happy… pos 0.8
# ('pos', 1.0)
# happy graduation, bang yedam @treasuremembers pos 1.0
# ('pos', 0.6)
# @StrawbraryLoL Happy belated birthday🎉😊✨ pos 0.6
# ('pos', 1.0)
# @xX_N4ZB0L_Xx I'm not that small! I have big muscles that makes up for it right? *ancom is very happy to be picked up* pos 1.0
# ('neg', 1.0)
# RT @ManUnitedZone_: Happy Birthday to Cristiano Ronaldo who turns 36 today! 🎉
#
# Sit back, relax and enjoy all 42 of his goals from the 2007… neg 1.0
# ('neg', 1.0)
# RT @ManUnitedZone_: Happy Birthday to Cristiano Ronaldo who turns 36 today! 🎉
#
# Sit back, relax and enjoy all 42 of his goals from the 2007… neg 1.0
# ('neg', 1.0)
# RT @MNELIAA: HAPPY “SAY YEAH” DAY 🤍
#
# 365 days
# 1 million views+
# 10 million streams across DSPs
# 30,000+ playlists on Spotify alone
# Nuffffffff… neg 1.0
# ('pos', 1.0)
# RT @A3Wiki: Tsumugi's stage actor, Yoshihiko Aramaki, turns 31 today! Happy birthday to him!🍳🎉 https://t.co/i1Ym8HLBLl pos 1.0
# ('neg', 1.0)
# RT @YGA_GLOBAL: Happy Graduation to #TREASURE's Bang Yedam 👏🎓
#
# @treasuremembers @ygtreasuremaker
# https://t.co/j4MIeWk6FI https://t.co/XYCi… neg 1.0
# ('neg', 1.0)
# RT @YGA_GLOBAL: Happy Graduation to #TREASURE's Bang Yedam 👏🎓
#
# @treasuremembers @ygtreasuremaker
# https://t.co/j4MIeWk6FI https://t.co/XYCi… neg 1.0
# ('neg', 1.0)
# RT @TiRon_: This video will always make me happy 😭 https://t.co/IRkti7e3oK neg 1.0
# ('pos', 1.0)
# @likahble heyyyy we're bday twinsies!!! happy bday&lt;33333333 pos 1.0
# ('pos', 1.0)
# RT @OrganicBabe_: I just want to say I am so fucking proud and happy for @moncherixxo. Behind closed doors she has been moving mountains! S… pos 1.0
# ('pos', 1.0)
# RT @taechimkiey03: Happy Birthday Taehyun! 🎉🎊👏 he's so talented, hardworking, handsome, smart, funny, witty &amp; a good-hearted bby. Pls be ou… pos 1.0
# ('pos', 1.0)
# RT @classy_rosie: #QiangJinJiu #将进酒
#
# I died a happy death https://t.co/vNQdWL2zku pos 1.0
# ('pos', 1.0)
# @jisungbagus HAPPY birthday cettaaa, have a great one!! &lt;3 https://t.co/d5Jc135PcL pos 1.0
# ('neg', 1.0)
# RT @TXT_bighit: [#태현생일_txt]
# 🐿HAPPY BIRTHDAY🐿
# 2월 5일
# 오늘은 태현데이!!!
#
# #혼자_있으면_큰 #호박이형아 #달빛정령 #잔디
# #투모로우바이투게더 #TOMORROW_X_TOGETHER #TXT https://t.c… neg 1.0
# ('pos', 1.0)
# I'm so happy for jojo siwa 😫 pos 1.0
# ('pos', 1.0)
# @p_oggers You are the best after all you are the only person who makes me happy pos 1.0
# ('pos', 1.0)
# RT @HeeYataethan: Hei baby taehyunie, happy birthday eoh.... Doa terbaik buat kamu, bahagia selalu, sehat terus, makin sukses, wish you all… pos 1.0
# ('neg', 1.0)
# RT @NCTsmtown: 🎂HAPPY BIRTHDAY TO #JISUNG
# WE💚YOU
#
# #HAPPYJISUNGDAY #지성
# #NCT #NCTDREAM https://t.co/oRsfGs680F neg 1.0
# ('pos', 1.0)
# RT @KALIUCHIS: happy anniversary to my first EP,
# Por Vida 🍰 https://t.co/EI36MeyI0r pos 1.0
# ('neg', 1.0)
# @sallieheart Happy Birthday 🎂 🥳 🎉 🎈 🎁 🎊 🙏❤ neg 1.0
# ('pos', 1.0)
# RT @KALIUCHIS: happy anniversary to my first EP,
# Por Vida 🍰 https://t.co/EI36MeyI0r pos 1.0
# ('neg', 1.0)
# RT @mingberg: @ReGener26717025 @nikki_tolich @mysageadvice @DocReoRants @Journeyingdave @JeriLowrance @VelvetSkye @Ceo_PCW @rootnk @IqPcw @… neg 1.0
# ('neg', 1.0)
# @onlyfanzpromozz https://t.co/Vo6Q9Lf64t neg 1.0
# ('pos', 1.0)
# @ShankiAustine it's nolonger Bayern Munich, am happy for us pos 1.0
# ('neg', 1.0)
# @sugasblunt OMFG HAPPY LATE BIRTHDAY ASH IM SO SORRY 🥺😭 neg 1.0
# ('neg', 1.0)
# RT @SB19Official: @stellberrycake [#SB19_STELLVESTER]: Advance Happy Birthday Maine!!!!! :D
#
# #SB19MENPA_Stell
# #SB19BBSocialTop5
# #SB19 neg 1.0
# ('neg', 1.0)
# RT @AbhilashKoliwad: Happy Birthday to the man, the myth, the King, the GOAT, the best, the most complete footballer ever. ❤️
#
# Thanks for m… neg 1.0
# ('neg', 1.0)
# RT @kinprikawaii: 紫耀くん今日も可愛かった♥️
# King &amp; Prince / I promise
# 　　　    ᕱ⑅︎ᕱ
#             (｡•ﻌ•｡ )
#   *▶◀⌒∪⌒∪⌒Ｙ⌒▶◀*．
#
# Little Christmas / Happy Hol… neg 1.0
# ('neg', 1.0)
# @TXT_members Taehynさん
# HAPPY BIRTHDAY🎈✨✨✨♬ neg 1.0
# ('neg', 1.0)
# HAPPY JISUNG DAYYYYY neg 1.0
# ('pos', 1.0)
# RT @GlobalBlackPink: please always keep that sweet gummy smile nini, you’re too precious and we must protect her🥺. Be happy, always jen. i… pos 1.0
# ('pos', 0.8)
# my granny told me “be a wise as a serpent and as humble as a dove” i love her so much, happy 21st to me and cheers to more life🥂 pos 0.8
# ('neg', 1.0)
# RT @NCTsmtown: 🎂HAPPY BIRTHDAY TO #JISUNG
# WE💚YOU
#
# #HAPPYJISUNGDAY #지성
# #NCT #NCTDREAM https://t.co/oRsfGs680F neg 1.0
# ('pos', 1.0)
# RT @KALIUCHIS: happy anniversary to my first EP,
# Por Vida 🍰 https://t.co/EI36MeyI0r pos 1.0
# ('pos', 1.0)
# @Asthygaus1 happy friday,don't skip ur breakfest,and take a bath.have a sweet day. aamiin. pos 1.0
# ('pos', 1.0)
# copious amounts of joy im so happy pos 1.0
# ('neg', 1.0)
# That sounds embarrassing. neg 1.0
# ('pos', 1.0)
# RT @syanne77: Happy Anniversary bubby. These two years have been amazing and I’m so excited for the many years to come. I commissioned some… pos 1.0
# ('pos', 1.0)
# Disobedient little cow thinks it’s ok to cum fucking slut is happy waisting his milk~ https://t.co/C4lkigqGDd pos 1.0
# ('pos', 1.0)
# RT @iconickdramas: And this is Run On's version of a happy ending. Living our normal daily lives 😭💛
#
# #RunOn #RunOnEP16 #RunOnFinale
#
# https… pos 1.0
# ('neg', 0.6)
# RT @rianhughes: I’m thinking of doing an XX Q and A. Not sure where or how - maybe right here on Twitter? A lot of people have interesting… neg 0.6
# ('pos', 1.0)
# RT @wolv_uchiha: @lovinmygirls218 @CartuneNetwerk Hate to break it to you but a large part of keeping our woman happy is suffering in silen… pos 1.0
# ('neg', 1.0)
# RT @NCTsmtown: 🎂HAPPY BIRTHDAY TO #JISUNG
# WE💚YOU
#
# #HAPPYJISUNGDAY #지성
# #NCT #NCTDREAM https://t.co/oRsfGs680F neg 1.0
# ('pos', 1.0)
# RT @Topnotch_Mae: Make sure you happy in real life not just the internet pos 1.0
# ('pos', 0.6)
# RT @TitanfallBlog: Look at these Legends.
#
# Happy 2 year anniversary, @PlayApex 🥳 https://t.co/vZgd1Y4AIo pos 0.6
# ('pos', 0.8)
# RT @chippolyta: This is the part where I remind you for no particular reason that this comic contains angst with a happy ending, and if you… pos 0.8
# ('neg', 1.0)
# what a sweetheart neg 1.0
# ('pos', 1.0)
# “Nobody is happy. You don’t get married to be happy. You get married so you have someone to share the unhappiness with”
# #FireflyLane pos 1.0
# ('neg', 1.0)
# RT @NCTsmtown: 🎂HAPPY BIRTHDAY TO #JISUNG
# WE💚YOU
#
# #HAPPYJISUNGDAY #지성
# #NCT #NCTDREAM https://t.co/oRsfGs680F neg 1.0
# ('neg', 1.0)
# RT @itangmoACN: 💙 Happy Friday 💙
# ขอให้เป็นศุกร์ที่สุขสุดสุดไปเลยยย⛅️🌈
# @winmetawin
# #HappyWinMonth
# #winmetawin https://t.co/pt2Rg6Vtt3 neg 1.0
# ('pos', 1.0)
# @chil00r Don't skip ur breakfast &amp;&amp; Have a great day be happy please 🍔 pos 1.0
# ('pos', 1.0)
# Karma real💯. You think everything going good and then boom you happy as can be and there goes karma knocking on yo front door 💯 pos 1.0
# ('pos', 0.8)
# happy black history month 💕 pos 0.8
# ('neg', 1.0)
# RT @_Bunalily: 🌻
#
#  --- Markhyuck Short AU
#
# "Wrong Target"
#
#  Genre : Romance, Semibaku,  bxb
#
#      Pair : MarkHyuck
#
# Prolog : Ketida… neg 1.0
# ('pos', 1.0)
# RT @UtdCode: Happy 29th birthday to the last Craftsman in our beautiful game Neymar JR https://t.co/tho5QiacPc pos 1.0
# ('pos', 1.0)
# RT @_BEPS1: Happy late birthday Er-gege!! 😩
# I meant for this to be a light hearted comic but it came out bittersweet LOL
# #魔道祖师 #蓝忘机0123生日快乐… pos 1.0
# ('neg', 1.0)
# RT @cnehshuga: LOML https://t.co/gxHqOt9FZk neg 1.0
# ('neg', 1.0)
# RT @spnajaaaaa: HAPPY BIRTHDAY, MY LOVE 🐿🤍
# สุขสันต์วันเกิดนะคะไอต้าวความรักของหนู คำอวยพรมันอาจจะซำ้ๆเดิมๆ แต่ก็ขอให้พี่มีความสุขมากๆนะคะ บ… neg 1.0
# ('pos', 1.0)
# RT @yabukimikan: Happy birthday to Minju，🎂🎉
#
# #민주로_물든_지금_영원해
# #AngelicMinjuDay
# #김민주 #KimMinju #IZONE  #아이즈원 https://t.co/NAWxJmeIUv pos 1.0
# ('pos', 1.0)
# RT @chaeyeonfiles: happy birthday to angelic minju, a vitamin to both izone and wizone, that makes everyone smile with her bright personali… pos 1.0
# ('neg', 0.8)
# RT @ilysmckann: Happy Birthday to Jisung and me ⋆·˚ ༘ *
# 🌷แจกการ์ดจีซอง ssgt aladin และ เงิน 100 บาท
# เนื่องในวันเกิดเค้าและจีซอง รีทวิตนี้… neg 0.8
# ('pos', 1.0)
# @luvruhoon happy birthday!💗💗 pos 1.0
# ('pos', 1.0)
# RT @KALIUCHIS: happy anniversary to my first EP,
# Por Vida 🍰 https://t.co/EI36MeyI0r pos 1.0
# ('neg', 1.0)
# Today Is Jisung Brithday
# .
# .
# .
# .
# #JISUNGday #JISUNG #NCT #NCTDREAM #NCT neg 1.0
# ('pos', 1.0)
# RT @likechizu: Jangan lupa bahagia ya kalian! U deserve to be happy too💞 pos 1.0
# ('pos', 1.0)
# RT @SuperSpoe: Trade with @darnact
#
# He wanted some Pacifica and I was happy to oblige https://t.co/W0MaLeGXTi pos 1.0
# ('pos', 1.0)
# RT @neymiana: Happy birthday to my GOAT 🐐 https://t.co/1qSA8UZGcZ pos 1.0
# ('neg', 1.0)
# RT @TXT_bighit: [#태현생일_txt]
# 🐿HAPPY BIRTHDAY🐿
# 2월 5일
# 오늘은 태현데이!!!
#
# #혼자_있으면_큰 #호박이형아 #달빛정령 #잔디
# #투모로우바이투게더 #TOMORROW_X_TOGETHER #TXT https://t.c… neg 1.0
# ('pos', 1.0)
# RT @Paula_White: Some people will never be happy for you because they can't be happy for themselves- pray for them. pos 1.0
# ('pos', 1.0)
# RT @KALIUCHIS: happy anniversary to my first EP,
# Por Vida 🍰 https://t.co/EI36MeyI0r pos 1.0
# ('pos', 1.0)
# @EmanRocketBall Now that’s profit really happy for you man pos 1.0
# ('pos', 1.0)
# RT @prkjisungiee: HAPPY BIRTHDAY PARK JISUNG
# sekarang udah legal dan makin kesini makin meresahkan.
# 사랑해 지성이 💚💚💚
#
# #StarOfStageJisungDay
# #NC… pos 1.0
# ('pos', 0.6)
# I'm so happy the spaghetti bowl is getting a facelift, don't get me wrong... but goodness gracious it is such a hea… https://t.co/RHavrqjPiY pos 0.6
# ('neg', 1.0)
# RT @StevePieczenik: No #NYTimes IS a laughing stock
# TY!
# #projectveritas for your commitment to expose
# The
# #FakeNews
# @nypost
# @ColumbiaBugle… neg 1.0
# ('pos', 1.0)
# RT @bIindeye: jojo siwa talking about her girlfriend has me crying happy tears 🥺  https://t.co/CxiCFFSG4S pos 1.0
# ('pos', 1.0)
# @sadlysummer Happy birthday 🥺❤️ pos 1.0
# ('neg', 1.0)
# RT @TXT_bighit: [#태현생일_txt]
# 🐿HAPPY BIRTHDAY🐿
# 2월 5일
# 오늘은 태현데이!!!
#
# #혼자_있으면_큰 #호박이형아 #달빛정령 #잔디
# #투모로우바이투게더 #TOMORROW_X_TOGETHER #TXT https://t.c… neg 1.0
# ('neg', 1.0)
# RT @YGA_GLOBAL: Happy Graduation to #TREASURE's Bang Yedam 👏🎓
#
# @treasuremembers @ygtreasuremaker
# https://t.co/j4MIeWk6FI https://t.co/XYCi… neg 1.0
# ('pos', 1.0)
# RT @Koreaboo: You may now be a legal adult (in Korea!) but you'll forever be NCT's and NCTzens' babie! Happy birthday to the bestest boy wh… pos 1.0
# ('pos', 0.6)
# @wjeffpetty @CBWatson3516 Happy anniversary guys!! pos 0.6
# ('pos', 0.8)
# RT @punya_may: Taehyun aa,,, Happy birthday🎉 always be happy and healthy!
#
# Ga kebayang kau poto itu aku cetak seukuran dinding kamar aku,br… pos 0.8
# ('neg', 1.0)
# RT @dongminori: THE FINALE EPISODE REALLY GAVE US A HAPPY SHIN SHIN COUPLE, A WELL DESERVED HAPPY ENDING 😍😍😍
# #차은우_막방까지_고생했수호
# #차은우 #TrueBeau… neg 1.0
# ('pos', 0.8)
# RT @Kinda_Lovable_: happy black history month https://t.co/zWyUTyNqQu pos 0.8
# ('neg', 1.0)
# RT @NCTsmtown: 🎂HAPPY BIRTHDAY TO #JISUNG
# WE💚YOU
#
# #HAPPYJISUNGDAY #지성
# #NCT #NCTDREAM https://t.co/oRsfGs680F neg 1.0
# ('pos', 1.0)
# RT @feyflk: If you ever get a chance to book with @BunnysTarot. I highly recommend it, I'm so happy I got to experience their work and I ca… pos 1.0
# ('neg', 1.0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-d8cfa73420c4> in <module>
#      36
#      37 twitterStream = Stream(auth, listener())
# ---> 38 twitterStream.filter(track=search_words)
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     349             next_status_obj = buf.read_len(length)
#     350             if self.running and next_status_obj:
# --> 351                 self._data(next_status_obj)
#     352
#     353             # # Note: keep-alive newlines might be inserted before each length value.
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _data(self, data)
#     321
#     322     def _data(self, data):
# --> 323         if self.listener.on_data(data) is False:
#     324             self.running = False
#     325
#
# <ipython-input-68-d8cfa73420c4> in on_data(self, data)
#      19         tweet = all_data["text"]
#      20         print(s.sentiment(tweet))
# ---> 21         sentiment_value, confidence = s.sentiment(tweet)
#      22         print(tweet, sentiment_value, confidence)
#      23
#
# ~\Documents\Vision\SentimentAnalysis\sentiment_mod.py in sentiment(text)
#     114 def sentiment(text):
#     115     feats = find_features(text)
# --> 116     return voted_classifier.classify(feats),voted_classifier.confidence(feats)
#
# ~\Documents\Vision\SentimentAnalysis\sentiment_mod.py in confidence(self, features)
#      27         votes = []
#      28         for c in self._classifiers:
# ---> 29             v = c.classify(features)
#      30             votes.append(v)
#      31
#
# ~\anaconda3\lib\site-packages\nltk\classify\naivebayes.py in classify(self, featureset)
#      87
#      88     def classify(self, featureset):
# ---> 89         return self.prob_classify(featureset).max()
#      90
#      91     def prob_classify(self, featureset):
#
# ~\anaconda3\lib\site-packages\nltk\classify\naivebayes.py in prob_classify(self, featureset)
#     113                 if (label, fname) in self._feature_probdist:
#     114                     feature_probs = self._feature_probdist[label, fname]
# --> 115                     logprob[label] += feature_probs.logprob(fval)
#     116                 else:
#     117                     # nb: This case will never come up if the
#
# ~\anaconda3\lib\site-packages\nltk\probability.py in logprob(self, sample)
#     520         """
#     521
# --> 522     def logprob(self, sample):
#     523         """
#     524         Return the base 2 logarithm of the probability for a given sample.
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style
import time

style.use("ggplot")

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

def animate():
    pullData = open("twitter-out.txt","r").read()
    lines = pullData.split('\n')

    xar = []
    yar = []

    x = 0
    y = 0

    for l in lines[-200:]:
        x += 1
        if "pos" in l:
            y += 1
        elif "neg" in l:
            y -= 1

        xar.append(x)
        yar.append(y)
        
    ax1.clear()
    ax1.plot(xar,yar)

ani = animation.FuncAnimation(fig, animate(), interval=1000)
plt.show()

# %% [markdown]
# ## Sentiment Analysis Youtube comments

# %%
import pandas as pd
import sentiment_mod as s

yt = pd.read_csv('UScomments.csv',encoding='utf8',error_bad_lines=False)
len(yt)
# Out:
# b'Skipping line 41589: expected 4 fields, saw 11\nSkipping line 51628: expected 4 fields, saw 7\nSkipping line 114465: expected 4 fields, saw 5\n'
# b'Skipping line 142496: expected 4 fields, saw 8\nSkipping line 189732: expected 4 fields, saw 6\nSkipping line 245218: expected 4 fields, saw 7\n'
# b'Skipping line 388430: expected 4 fields, saw 5\n'
# C:\Users\rodri\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# 691400

# %%
yt.head()
# Out:
#       video_id                                       comment_text likes  \
# 0  XpVt6Z1Gjjo                  Logan Paul it's yo big day ‼️‼️‼️     4
# 1  XpVt6Z1Gjjo  I've been following you from the start of your...     3
# 2  XpVt6Z1Gjjo                 Say hi to Kong and maverick for me     3
# 3  XpVt6Z1Gjjo                                MY FAN . attendance     3
# 4  XpVt6Z1Gjjo                                         trending 😉     3
#
#   replies
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
comments = yt['comment_text'][:1000]

for comment in comments:
    print(s.sentiment(comment))
    sentiment_value, confidence = s.sentiment(comment)
    print(comment, sentiment_value, confidence)
        
    if confidence >= 0.8:
        with open('youtube-out.txt', 'a') as output:
            output.write(sentiment_value)
            output.write('\n')
# Out:
# ('neg', 1.0)
# Logan Paul it's yo big day ‼️‼️‼️ neg 1.0
# ('neg', 1.0)
# I've been following you from the start of your vine channel and have seen all 365 vlogs neg 1.0
# ('neg', 1.0)
# Say hi to Kong and maverick for me neg 1.0
# ('neg', 1.0)
# MY FAN . attendance neg 1.0
# ('neg', 1.0)
# trending 😉 neg 1.0
# ('neg', 1.0)
# #1 on trending AYYEEEEE neg 1.0
# ('neg', 1.0)
# The end though 😭👍🏻❤️ neg 1.0
# ('neg', 1.0)
# #1 trending!!!!!!!!! neg 1.0
# ('neg', 1.0)
# Happy one year vlogaversary neg 1.0
# ('neg', 1.0)
# You and your shit brother may have single handedly ruined YouTube.....thanks... neg 1.0
# ('neg', 1.0)
# There should be a mini Logan Paul too! neg 1.0
# ('neg', 1.0)
# Dear Logan, I really wanna get your Merch but I don't have the money. We don't even have a Car. It would really make my day to have any of your merch neg 1.0
# ('neg', 1.0)
# Honestly Evan is so annoying. Like its not funny watching him try to be famous he's trying way to hard and I don't like it neg 1.0
# ('neg', 1.0)
# Casey is still better then logan neg 1.0
# ('neg', 1.0)
# aw geez rick this guy is the face of YouTube. neg 1.0
# ('pos', 1.0)
# He happy cause he in a movie pos 1.0
# ('neg', 1.0)
# Ayyyyoooo Logang what up .  This was a hard vlog to watch Logan how dare are you to destroyed that YouTube bag . Logang Army check my covers and share them  can Logang help me to hit 1,000 Subscribers today, I think we can do it SUBSCRIBE neg 1.0
# ('pos', 1.0)
# Bro y didnt u give merch to johannes he is ur boy 2 pos 1.0
# ('neg', 0.8)
# It's been fun watching you grow. I'm at 42 days straight and can't seem to grow. Any advice? neg 0.8
# ('neg', 1.0)
# Made a lot of people hate youtube - GJ neg 1.0
# ('neg', 1.0)
# NO HONEY NOOO can't believe he has almost 12 mili in a year damnn neg 1.0
# ('neg', 0.8)
# Jake Paul is the fastest growing channel to hit 10 Million and thats a fact and is u dont want to believe that then just dab away neg 0.8
# ('neg', 1.0)
# lol PEWDIEPIE accidentally played song with words nig%%r during his stream, u can watch that part on my channel, i've just uploaded. Like so more ppl could see this neg 1.0
# ('neg', 1.0)
# You should do a prank that you broke  your play puttun neg 1.0
# ('pos', 1.0)
# I love Logan and Jake so much and thay are so amazing and I look up to them so much 😍💋💙👍 pos 1.0
# ('neg', 1.0)
# #1 on Trending let's go. neg 1.0
# ('neg', 1.0)
# Evan was being such a dick on this vlog neg 1.0
# ('neg', 1.0)
# if you get allot of diss likes do you get on the top comments? lets see diss like this please neg 1.0
# ('pos', 1.0)
# Evan is a horrible human being he also looks so jealous when you open it like he should be happy for you pos 1.0
# ('pos', 1.0)
# I love you so much I love to meet you But I live in Israel You really inspire me I really like your channel Keep doing what you do\nBecause everyone loves it and will be Unique and Pashan will be creative and I hope you will see it bye pos 1.0
# ('pos', 1.0)
# 👈 watch by clicking here you can see people's are entertaining pos 1.0
# ('neg', 1.0)
# I was dying when he threw the midget on the ground at the end LMAO neg 1.0
# ('neg', 1.0)
# Technically it was Logan cos Jake started his channel in 2013 neg 1.0
# ('neg', 1.0)
# Logan's 4 life all the way from England neg 1.0
# ('pos', 0.8)
# Gotta love Youtube for giving morons the ability to earn a buck from other morons. pos 0.8
# ('pos', 1.0)
# Evan is being a douch Logans getting pissed, Logan should have went to smash his game system then evan would have cried 😂 & Evans not gonna be able to take care of a pitbull tell his ass no, its gonna kill kong !!! pos 1.0
# ('neg', 1.0)
# Can the Pauls please stop saying they're the fastest growing YouTube channels?! That's PewDiePie's position!! He made managed to get all the subscribers you guys have in 6 MONTHS!!! Why is that so hard to understand?! neg 1.0
# ('neg', 1.0)
# Why is trump trending on YouTube .. oh wait this isn't trump sure looks like him tho neg 1.0
# ('neg', 1.0)
# When I saw this vid at first I was like naaahhhhh to tired but I looked at it again and saw the title and I was like H🔥LLLLLLZZZZ YEEEAAAHHHH and as a anniversary present Logan Paul I'm gonna b u for Halloween to show how much u hav changed ma life and I'm not even joking about it 😂😂😂 neg 1.0
# ('neg', 1.0)
# I subscribed today. This was only the second video I've watched and I had no idea it was a year special. neg 1.0
# ('neg', 0.6)
# Jake started YouTube 3 years ago his first vid is 3 years ago so technically Logan hit it first neg 0.6
# ('neg', 1.0)
# The girl with the dog was kylie Jenner 😂 neg 1.0
# ('neg', 1.0)
# Not a hater but fuck you neg 1.0
# ('neg', 1.0)
# Where is the other dog neg 1.0
# ('neg', 1.0)
# I go out of my way to dislike every single one your videos neg 1.0
# ('neg', 1.0)
# This looks like a great video, but after you are done would you be kind enough to check out my new YouTube channel and give me some feedback? Maybe even subscribing? :) neg 1.0
# ('neg', 1.0)
# Get the diamond play button appraised neg 1.0
# ('neg', 0.8)
# Ok. So if you would. What editing things do you use for your videos? I'm trying to start but have no idea how to make cool edits. neg 0.8
# ('neg', 1.0)
# why is the thumbnail so threatening neg 1.0
# ('neg', 1.0)
# He talking about how we changed logging Forever on his own channel should be a lot more humbling if somebody else made this video instead of you know Logan Paul make it a video about how Logan Paul change login forever you didn't change shit if anything you just exposed a large audience of five to 10 year olds maybe even freshman in high school that like your videos people that you can hook up with or fuck really sad and it's really pathetic how your entire audience is made up of these people nobody can actually buy or afford anything without asking their parents that's exactly who your audience is neg 1.0
# ('neg', 1.0)
# FUCK THIS DUDE AND HIS BROTHER. neg 1.0
# ('neg', 1.0)
# by the way why do you have a card board of the picture of alya do you like to look at it lol neg 1.0
# ('neg', 1.0)
# Just a tad arrogant with the title, huh? neg 1.0
# ('neg', 1.0)
# Evan is just taking ur money for granted cause he said if his Rolex had fake diamonds he wouldn't be ur friend anymore and he left when u said the diamond was real, but don't keep commenting it's probably a joke cause ik it might be but my opinion is that he's using Logan's money for granted neg 1.0
# ('neg', 1.0)
# Omg he broke his play button box neg 1.0
# ('neg', 1.0)
# Get off of YouTube you spoiled Hollywood brat. neg 1.0
# ('neg', 1.0)
# Attack of titan squad were u at👻❤️😂 neg 1.0
# ('pos', 0.6)
# Congrats Logan love u so much someday I would love to meet u #1 fan of the logang ❤️ pos 0.6
# ('pos', 1.0)
# Um well not the best Vlog was expecting more but congrats pos 1.0
# ('pos', 1.0)
# Evan lowkey is starting to piss me off! pos 1.0
# ('neg', 1.0)
# tone it down fgt you didn't change youtube neg 1.0
# ('pos', 1.0)
# You all are worms. Congrats for being simple minded. pos 1.0
# ('neg', 1.0)
# ░░░░░▐▀█▀▌░░░░▀█▄░░░\n░░░░░▐█▄█▌░░░░░░▀█▄░░\n░░░░░░▀▄▀░░░▄▄▄▄▄▀▀░░\n░░░░▄▄▄██▀▀▀▀░░░░░░░\n░░░█▀▄▄▄█░▀▀░░\n░░░▌░▄▄▄▐▌▀▀▀░░ THIS IS BOB\n▄░▐░░░▄▄░█░▀▀ ░░\n▀█▌░░░▄░▀█▀░▀ ░░ COPY AND PASTE HIM\n░░░░░░░▄▄▐▌▄▄░░░ SO HE CAN TAKE\n░░░░░░░▀███▀█░▄░░ OVER YOUTUBE\n░░░░░░▐▌▀▄▀▄▀▐▄░░\n░░░░░░▐▀░░░░░░▐▌░░ neg 1.0
# ('pos', 0.8)
# No one fucking cares. You're a 12 year old. There comes a point where you're too old for the whole I'm so goofy and fun every second of every day schtick. Yeah you're impressing douchey 14 year olds who waste their lives on YouTube but to the real world you and your fucktard brother are nothing more than a pair of over privileged, white privileged toddlers. Grow the fuck up man. You think this will be your life forever. One day you're going to face the real world and realize you can't just jump around and scream your way to a real job. Or you can't hair flip your way out of an inevitable date rape charge. pos 0.8
# ('pos', 1.0)
# yu are the best pos 1.0
# ('neg', 1.0)
# Well done I LOVE! You so much :D neg 1.0
# ('pos', 0.8)
# I am very happy for this man and we need to spread more love. United we stand, divided we fall. pos 0.8
# ('neg', 1.0)
# Me and my friends subscribe AAAAAAAAAAAA you got the Diamond Play button 💎😆😆😆😆😆😆😁😁😁😁😁😁😁 neg 1.0
# ('neg', 1.0)
# I like you logan but your brother is a menace to youtube neg 1.0
# ('neg', 1.0)
# Hay login were is my March I bought it 3 months ago neg 1.0
# ('neg', 0.8)
# OMG u made this vid on my bday neg 0.8
# ('neg', 1.0)
# I was the 50k sub and now this! neg 1.0
# ('neg', 0.8)
# 😂😂😂😂😭 I love Evan so much!!! neg 0.8
# ('pos', 1.0)
# it's everyday bro pos 1.0
# ('neg', 1.0)
# DAFUQ did  i just watch ;) neg 1.0
# ('neg', 1.0)
# Jake Paul ? Who neg 1.0
# ('neg', 1.0)
# Pls subscribe to my channel neg 1.0
# ('neg', 1.0)
# Logang gang gang neg 1.0
# ('neg', 1.0)
# Whooooo.   Let's go Logang neg 1.0
# ('neg', 0.6)
# 1 on trending good job neg 0.6
# ('neg', 1.0)
# 365 days \n364 vlogs neg 1.0
# ('neg', 1.0)
# M neg 1.0
# ('neg', 1.0)
# My balls are itchy..... neg 1.0
# ('neg', 1.0)
# Sum ass Logan neg 1.0
# ('neg', 1.0)
# what happen if Mavrick die neg 1.0
# ('neg', 1.0)
# This is shit. neg 1.0
# ('neg', 1.0)
# 1 on trending !!!!!! neg 1.0
# ('neg', 1.0)
# # be a gote neg 1.0
# ('neg', 1.0)
# my neg 1.0
# ('neg', 1.0)
# Tomorrow is my Birthday neg 1.0
# ('neg', 1.0)
# #1 on trending.................... neg 1.0
# ('neg', 1.0)
# #1 on trending, FUCK YES! neg 1.0
# ('neg', 1.0)
# hi first neg 1.0
# ('neg', 0.8)
# Woooooooooooooooow my boy neg 0.8
# ('neg', 1.0)
# Happy vlogiversary neg 1.0
# ('neg', 1.0)
# #1 trending whoaaaa neg 1.0
# ('neg', 1.0)
# MY BOIIII IS #1 TRENDING LMAO neg 1.0
# ('neg', 1.0)
# #1 on treading!!! neg 1.0
# ('neg', 0.8)
# *eyyyjooooo Good morning loooganng WHATS POPPPINNN?!?* neg 0.8
# ('neg', 1.0)
# Good Job on trending Logan. neg 1.0
# ('pos', 1.0)
# Love you Pewdiepie don't apologize your fine pos 1.0
# ('pos', 1.0)
# I am seeing so much idiocy and lack of self awareness in these comments. Let me hit you all with some knowledge: the N word is not okay to say because it has body counts and a huge amount of human suffering attached to it. The word goes back to slave owning days, same as the N word with no hard r. Black folks can say the word because it is theirs to reclaim. I'm a person of color and that word is not in my vocabulary. Why? Because I'm not black, and I'm aware of the oppression tied to this word. I'm also not a piss baby arguing why I should be able to use such a gross word because again, this word is not mine to reclaim. So yeah, it's fine when all these black rappers use the word because it's a part of their personal history. As a grown ass woman I am still in disbelief that people can't have a pinch of empathy for their fellow human beings. If you're not black, you are irrelevant in the conversation of whether you can say the n word. You can't, bottom line, and if you're still arguing your right to say it, well then I have news for you: you're a racist. pos 1.0
# ('pos', 0.8)
# Pewds we are all behind you. This is just another attack on your character. We love you pos 0.8
# ('pos', 1.0)
# You're telling me that you're not perfect and sometimes you fuck up? \nThat's wired.. pos 1.0
# ('neg', 1.0)
# Everybody says that when u play call of duty and other games it's immature but can be over looked by great people it takes someone low to sit and fight about it it's life man neg 1.0
# ('neg', 1.0)
# Never apologise to the regressives neg 1.0
# ('neg', 1.0)
# dont be sorry pewds, EVERYBODY says something  bad everyday, but your a public person and says this ONE time and get fukin news all over the world talking about it.. jeeezyys, keep on doing what your doing niggah neg 1.0
# ('pos', 0.6)
# Other streamers do the same thing and don't apologize. Here is a prime example of a truly moral person he tries so hard even censors himself to try and be a good example but he makes one tiny mistake and they attack him.  I saw an example where a teachers writes the time tables for 9 he starts by writing 9x1=10 then writes the rest right. The kids make fun because he got one wrong but fail to acknowledge that the rest are correct it goes to show people will quickly make fun of your mistakes but ignore your accomplishments. Keep doing what you're doing pewds you truly are an inspiration pos 0.6
# ('pos', 0.6)
# PROCEED WITH CAUTION: \nThis comment section will give you stage 4 cancer immediately. pos 0.6
# ('neg', 1.0)
# this isn't a bad thing... shit happens neg 1.0
# ('neg', 1.0)
# I forgot that pewdiepie's fandom is a majority white people 😒.\n IF 👏 YOU'RE 👏 WHITE 👏 DONT 👏 TELL 👏 POC 👏 HOW 👏 THEY 👏 SHOULD 👏 FEEL 👏. Our ancestors paid for that word with their own blood, so poc today can use it how ever we want. You cannot tell us how we should feel. Y'all are disgusting for backing up your problematic fave and I'm pretty sure he did this before. Pewdiepie is canceled. neg 1.0
# ('pos', 1.0)
# And this could in all honestly become a good thing for you. You sit on a platform where you could really educate people especially when so many of your fans seem to think it's okay to be said. Really learn about the history of the word and come back to us if you can because you could really help educate people and that's powerful. pos 1.0
# ('pos', 1.0)
# What the hell is wrong with everyone who's talking badly about him he said the word by accident it's ok pewdiepie you're super cool we all love you the people who are here and supporting you😊❤️ pos 1.0
# ('neg', 1.0)
# OK guys i get that the word was once used as a demeaning term and that the history of that word will never change, yes pewds fucked up but still it quite obviously wasn't his intention to use the word in a racist way. And those people overreacting are making it easier for toxic media influencers  to fuck every single content creator because they are blowing this out of proportion, pewds is not a racist. neg 1.0
# ('neg', 1.0)
# pewdiepie had nothing to be sorry about.  everybody who is mad at him need to get their head out of their ass and get over themselves.  or maybe when a black person makes an offensive remark about a white person i should call them racist and see how they like it.  turn about is fair play. neg 1.0
# ('pos', 1.0)
# I think other YouTube's who are hatting at him are just jealous that he is bigger than them. I think yes it was wronge for him to say it but common give this guy a break ok I have heard this word said by black people daily if they can say it why can't white people why so sensitive. I am Indian and have heard Sooo much rasisum from every body including black and white people. This is outrageous I am pissed and not happy u can clearly see he was hyped up at the time when he said this can't u actually just support him and understand that he is a human as well pos 1.0
# ('pos', 0.6)
# Oh no you're famous so theyre take this outta proportion, keemstar and idubbz didnt get attacked by media just because theyre smaller pos 0.6
# ('neg', 1.0)
# Y'all will forgive him for anything lol neg 1.0
# ('neg', 1.0)
# i think its funny how he said one word and all of the sudden its the end of the world i get it words hurt but you all need to grow up honestly because i can say this the fact that you get offended by a word is dissapointing like seriously theres so much worse one youtube but no one does anything about that grow up!! and at least he had the decency to own up to what you did he said this to everyone in the entire world lets you get on camara and apologize infront of millions of people i bet you cant do it.. neg 1.0
# ('neg', 1.0)
# I am not angry at you at all.  And you shouldn't have to apologize.  The way I see it, if it's such a bad word then NO ONE should be using it.  Not just white people.  I support you Pewds! neg 1.0
# ('neg', 1.0)
# HUMANS MAKE MISTAKES\n\nIF YOU HAVENT MADE THEM, YOU ARENT HUMAN. neg 1.0
# ('neg', 1.0)
# i am convinced a large percentage of PewDiePie's audience are 12 year old white boys who think they are edgy by saying the N word. neg 1.0
# ('neg', 1.0)
# I don't see it as racist, but rather as an accident neg 1.0
# ('pos', 1.0)
# I like how when other people say these things its fine but when a famous person says this everyone loses their heads pos 1.0
# ('neg', 1.0)
# People mad because he said the n word!? He said it by accident cause everyone does it neg 1.0
# ('pos', 0.6)
# Its just a word, calm down pos 0.6
# ('pos', 1.0)
# lets be honest here guys, we all have let the word slip before... cmon now lol, we are confronted with the word on tv, music, shows, friends, cmon now we have all let it slip atleast once....  lets not front pos 1.0
# ('neg', 1.0)
# To the people saying that since black people say it why does it matter if another race says it this is one of many reasons why our society is shit now. It doesn't matter if black says it that doesn't justify other groups using the term shit like that doesn't just slip out that's the worst word you can think of ? It's scary how dumb a lot of people are in these comments we've got a lot of work to do America. Some of your reasoning validation his reasoning for using the word is ridiculous. #SMD neg 1.0
# ('pos', 1.0)
# So humble! It's ok Pewds, u didn't mean to cause the drama that crowds try to create. U are a good example to your fans. pos 1.0
# ('pos', 1.0)
# 👈 watch by clicking here people's are entertaining pos 1.0
# ('neg', 1.0)
# Listen listen, it's not up to white people to judge or criticize you for what you said, the word you said it's a offensive slang to black people if anyone has the right to be offended is them. So, please , people on the comments, stop saying it's just a word or I feel offended for them . Let them say what they think about what happened. neg 1.0
# ('neg', 1.0)
# What did he say?? neg 1.0
# ('neg', 1.0)
# Honestly, who is not racist (in their own way) nowadays? Even ppl make jokes of asian having small eyes ...it's common and no it doesnt affect me LOL PLUS HE DIDNT SAY IT OWN PURPOSE ! IF HE REALLY MEANT IT, WHY WOULD HE SAY SORRY :/ neg 1.0
# ('neg', 1.0)
# If your not black you have no right to say that word point blank period neg 1.0
# ('neg', 0.8)
# I'm white ok I don't know if it really is offensive at all. BUT HOW THE FUCK DOES HIM SAYING THIS AFFECT YOU AT ALL. He didn't say anything about someone trying to be mean to them. Y'all need to chill. neg 0.8
# ('neg', 1.0)
# Sticks and Stones may break my bones but words will never hurt me neg 1.0
# ('neg', 1.0)
# Don't apologize. Political correctness is the newspeak word for leftist censorship.  All these media outlets just trying to bring you down solely because you seem to be somewhat right winged. The fucking Wall Street Journal tried the same thing few months ago and they failed lmao neg 1.0
# ('neg', 1.0)
# I forgive you but man i can you blame people for saying the n word we say it ourselves neg 1.0
# ('neg', 1.0)
# Social justice warriors need to chill neg 1.0
# ('neg', 0.6)
# As a Black American, I don't think it's that big of a deal. I haven't even seen the clip but from what I've heard and from what I know about Pewds from watching him for years, I can conclude it wasn't meant to be offensive. Lots of the time the word is used now (or its variants), it's not meant to be racist or worth getting offended over. Although, I don't get why people have this weird obsession with saying it. While context does matter, regardless, it's a word with a shitty history and unnecessary to use. When people have a fixation with the word it weirds me out and makes me think they're closet racists. Do people think it's edgy or something? (I'm talking primarily about nigger, not nigga because that word has a totally different connotation) neg 0.6
# ('neg', 1.0)
# Saying Nigga isn't even bad it's only bad if you say it in a hateful way to black people ALL THE CRY BABIES and immature people stop going at him I guarantee youse you wouldn't say it to idubbz or others but because it's pewdiepie you think you have the right to go full force at him Yet I can see were people are coming from because pewdiepie did start the biggest ad crisis on any platform ever he has to much pressure on  him that's my speech down 😂😂 btw I do like idubbz it was just an example neg 1.0
# ('neg', 1.0)
# say the N word is not alright at all, but people are overreacting waaaaay too much neg 1.0
# ('neg', 1.0)
# Idubbbz says niggerfaggot in like every single video a year ago and it's hilarious. Everyone's such a boner. Love you Felix neg 1.0
# ('neg', 1.0)
# If u are really sorry, donate money to africa that you got from making this video. neg 1.0
# ('neg', 1.0)
# Poods, irrespective of your intentions (which I genuinely believe are pure and not hateful), you are a public face and voice and what you say and do influences others greatly. It's really disappointing to see that you still struggle to really respect the influence you have on YouTube and to your 57 million audience. I hope you wake the fuck up and stop this shit because you're a good, entertaining guy who really is and should be better than this. I hope you turn things around bro. Be more woke. neg 1.0
# ('neg', 1.0)
# It's okay man👌👌 neg 1.0
# ('neg', 1.0)
# Weird, my thumbs up doesn't stay. Could it be corrupted YouTube again? neg 1.0
# ('neg', 1.0)
# The day nobody cares about the word is the day it loses its power over people. Don't try to tell me that I'm only saying this because I don't UNDERSTAND. I DO. People have been slaughtered before, Countries have been Defiled AND ENSLAVED.. USED AS PROSTITUTES. NOT ONLY YOU... WHY DO I FEEL LIKE YOU GUYS ARE LETTING THIS N WORD STILL ENSLAVE YOU? neg 1.0
# ('neg', 1.0)
# Who gives a Shit . neg 1.0
# ('pos', 0.6)
# THERE ARE PEOPLE SUFFERING FROM HURRICANES AND YET Y'ALLZ ARE WORRIED ABOUT SOME CRACKA WITH A POTTY MOUTH???\n\nSincerely, your friendly neighborhood Beaner. pos 0.6
# ('neg', 1.0)
# honestly I don't care I won't let the word overpower me, I always will care about you pewdie! neg 1.0
# ('pos', 1.0)
# say the word cracker.. journos wont care because theres a huge double standard and they hate white people! pos 1.0
# ('neg', 1.0)
# This guy's face screams 'I'm gonna kill myself'. He seems to have lost all zest for life. neg 1.0
# ('neg', 1.0)
# Blacks folks say that shit with every sentence and when whitey says it on accident without disrespectful thoughts the whole world turns. neg 1.0
# ('pos', 1.0)
# It's ok Felix. pos 1.0
# ('neg', 0.8)
# I think it is okay, you are sorry about that and it is done. Strange is, that we have here 2 kind of people. 1 which can say this word with N and nothing happen und the other people where everybody get insane. Just think of it. neg 0.8
# ('pos', 1.0)
# Power is the disease.  Care is the cure.  Keep caring for yourself and others as best as you can.  This is life. pos 1.0
# ('neg', 1.0)
# 20 likes and I’ll eat a pickle neg 1.0
# ('pos', 1.0)
# How many sorrys can one say and still be able to be a part of YouTube pos 1.0
# ('neg', 1.0)
# Real life racism in the world<Guy says dum shit on a video game.. neg 1.0
# ('neg', 1.0)
# People in the coments you are stupid hes an adult its not a mastake he should know not to say it stop defending him all the time neg 1.0
# ('neg', 1.0)
# Y'all are stupid neg 1.0
# ('neg', 1.0)
# I bet you only 10% of the people getting triggered by him saying the n word are actually black. neg 1.0
# ('neg', 1.0)
# Hey Felix who care? The context is what matters. We know you are not a racist. Don't feed into these stupid narratives. neg 1.0
# ('pos', 1.0)
# Hi Felix. As an newly subscriber and a fan, I didn't see the bit your apologizing for on your channel but heard the douchebag Sargon of Akkad (not a fan) mentioned it on his channel, where he's clearly stating that it's more then ok to use that particular word if one is not a racist and actually said it multiple times. You clarly have more integrity and a higher moral character then he has and as a Albanien-Swed, am verry proud of you for apologizing. Big UP Brah! pos 1.0
# ('neg', 1.0)
# Ive said some hateful shit while playing video games and i tend to rage to and in that rage i probably shouldn't have said some stuff that i did but idgaf neg 1.0
# ('neg', 1.0)
# I defended pewds the last racist thing he did. Pewds isn't racist, that's just his inappropriate, dark humor. There's no need to be sensitive, but if you're accidentally racist on several occasions it's not an accident and you're actually racist. I've never ever said the n word, because from a white person that's a terribly hurtful word, and with the black family members that I have, I would never want my young cousins to hear the word that came out of this mans mouth, especially since he's an influencer. Now I'm going to be hearing it more, and then hear well pewdiepie said it, so can I. It's not okay, and it's not something you say in the heat of the moment, it only slips out if you frequently say it. I think I gotta give up on defending this. I've been subscribed for like 6 years. And it's time to say farewell. neg 1.0
# ('neg', 1.0)
# Pewdiepie puts up a sorry video for saying the N word.\n\n90% of the comments are people typing it. neg 1.0
# ('neg', 1.0)
# You are basically the face of YouTube. For someone who has woken up from a coma since before YouTube was around you'd be the first thing they'd know about YouTube. I know you have all this pressure under your shoulders because if you say anything wrong, it would be like the YouTube logo walked on stage and said: Fuck off! \n\nIt's hard to control how you are and speak, I know it, and I feel bad for you. You didn't have to apologize, as you said nigger to a yellow fucking blob, but you did. neg 1.0
# ('neg', 1.0)
# All these people that are saying you should say what ever you want are also trump supporters. neg 1.0
# ('neg', 1.0)
# Pewd you don't have anything to apologize for... it's just a word neg 1.0
# ('neg', 1.0)
# Thank you for apologizing pewds, i haven't lost respect for you neg 1.0
# ('neg', 0.8)
# Sh*t happens carry on neg 0.8
# ('pos', 1.0)
# Dude it's just a word. Maybe ppl shouldn't be getting so butt hurt to be honest. pos 1.0
# ('neg', 1.0)
# It's not like he said Voldemort. Ain't no evil wizards gonna come out if you say the n word neg 1.0
# ('neg', 1.0)
# lol its just a word neg 1.0
# ('pos', 0.6)
# If a black american says the n word it's called slang. If a black american can call us white people or typical white girls it's called fun. But if a white person says the n word he's a racist. K den pos 0.6
# ('pos', 1.0)
# People give power to the word they don't want to hear. If someone says the N word, let it slide. Because you're the one who's making it a bigger deal. Stop caring and things will cool off pos 1.0
# ('neg', 1.0)
# Everyone makes mistakes. neg 1.0
# ('neg', 1.0)
# Nice kaws statues dude neg 1.0
# ('neg', 1.0)
# Fuck niggers. neg 1.0
# ('neg', 1.0)
# https://youtu.be/XBJtNAhVLag neg 1.0
# ('neg', 1.0)
# Food for thought everybody: https://www.youtube.com/watch?v=IzloFCxX7HQ neg 1.0
# ('neg', 1.0)
# Adamsın neg 1.0
# ('neg', 0.8)
# damn nigga neg 0.8
# ('neg', 0.8)
# *nigge whut?* neg 0.8
# ('neg', 1.0)
# Niggers neg 1.0
# ('neg', 1.0)
# Nigga neg 1.0
# ('neg', 1.0)
# PUSSY neg 1.0
# ('neg', 1.0)
# #deletethischannel neg 1.0
# ('neg', 1.0)
# Pewdiepie... bumass nigga, lmao. neg 1.0
# ('neg', 1.0)
# Nigga neg 1.0
# ('neg', 1.0)
# It's okay pewds neg 1.0
# ('neg', 1.0)
# Fucking nigger neg 1.0
# ('pos', 0.6)
# Love ya Felix pos 0.6
# ('neg', 1.0)
# fuckniggers neg 1.0
# ('neg', 1.0)
# nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nig ...
# ('neg', 1.0)
# smd neg 1.0
# ('neg', 1.0)
# Negerboll neg 1.0
# ('neg', 0.6)
# What if I wanna unlock my phone while in the bed in the dark neg 0.6
# ('pos', 1.0)
# 🤔how will girls unlock their iphone X after taking off their makeup? pos 1.0
# ('neg', 1.0)
# I've said it once and I'll say it again: I only sniff poop not eat it! neg 1.0
# ('neg', 1.0)
# I could’ve sworn we asked for group FaceTime call . neg 1.0
# ('neg', 1.0)
# What if you are wearing sunglasses? neg 1.0
# ('neg', 1.0)
# So many people wana see face id security flaw..... neg 1.0
# ('pos', 1.0)
# 👈 watch by clicking on icon people's are entertaining pos 1.0
# ('pos', 1.0)
# I ll still buy an iphone 6s coz it hs headphone jack and finger print sensor pos 1.0
# ('neg', 1.0)
# I'm just not impressed neg 1.0
# ('neg', 1.0)
# Looks outdated with the chrome. neg 1.0
# ('neg', 1.0)
# Still made in China neg 1.0
# ('neg', 1.0)
# Let time and technology turned iPhone X cheaper. For now I'll settle down with my secondhanded 6s. I have skipped 7 anyway and definitely won't buy 8. neg 1.0
# ('neg', 1.0)
# How are Chinese going to secure their phones??? neg 1.0
# ('neg', 1.0)
# The phone itself looks pretty great but it isn't worth the $1,000. I'd say wait a while before buying it so the price can lower. By March next year it's probably gonna be the same price as the IPhone 7 is now. neg 1.0
# ('neg', 0.8)
# 1,000 ?! . No thank you . Great phone tho . You know how many things I can buy with that neg 0.8
# ('pos', 0.8)
# I'm not an apple fan, had iPhones for years in the past before being overcome with boredom stemming from the stagnant design and underwhelming yearly reveals. Currently loving on my gorgeous s8 plus, HOWEVER, the iPhone X is absolutely beautiful, and for the first time in years I'm actually kind of excited about an apple product. Also can't wait to see how Samsung responds, competition means better products for consumers. Nice work apple:) pos 0.8
# ('neg', 1.0)
# Xcuse me, what was the price again? neg 1.0
# ('neg', 0.6)
# What if it's to dark to recognise youre face how do you unlock it? neg 0.6
# ('neg', 1.0)
# Damn I wonder how much longer until we're looking like futuristic movie neg 1.0
# ('pos', 1.0)
# Apple doing a good job copying Samsung but whatever happened to being innovative? This is just overpriced android with an apple logo. pos 1.0
# ('neg', 1.0)
# It's apple so all of my friends probably automatically hate it neg 1.0
# ('neg', 1.0)
# Anyone else appreciate their 6/6s more now? neg 1.0
# ('neg', 1.0)
# I don’t really like the no home button :(( I like Touch ID more then this face id neg 1.0
# ('neg', 0.6)
# When Google did face unlock several years ago, the entire tech press dismissed it as a gimmick. Now it is the best thing since sliced bread. neg 0.6
# ('neg', 1.0)
# Those prices though....I'll stay with my zte . neg 1.0
# ('neg', 1.0)
# I feel like with no home button, you're constantly going to accidentally open the 4 apps at the bottom of the screen. neg 1.0
# ('neg', 1.0)
# iPhones are for cool hip people, and Samsungs/androids are for fob immigrants and old people, that's what I've noticed neg 1.0
# ('neg', 0.8)
# This thing is an orwellian nightmare George Orwell couldn't think of anything better in a drug induced dream. Apple should pay you to buy it. neg 0.8
# ('neg', 1.0)
# YAS Can't wait to get it! I just need to sell my kidney so I can afford iPhone X :D neg 1.0
# ('neg', 1.0)
# People here at work think this phone is the best phone ever made and no other phone has the features it will have.....I sit and listen o them at the lunch table browsing YouTube on my S8 smiling.  :) neg 1.0
# ('neg', 1.0)
# why did they get rid of the button smh neg 1.0
# ('neg', 0.6)
# NSA loves Apple users the most. neg 0.6
# ('neg', 1.0)
# BOUT TIME APPLE!! Been rocking iPhone since the start. Nothing has changed, FINALLY SOMETHING GREAT! neg 1.0
# ('neg', 0.8)
# *AND THEY DON'T STOP COMIN AND THEY DON'T STOP COMMIN AND THEY DON'T STOP COMMIN AMD THEY DON'T STOP COMM-* neg 0.8
# ('neg', 1.0)
# TF the back is uglier than the iPhone four neg 1.0
# ('neg', 0.8)
# No thank you! I'm stuck with the last pos they sold. neg 0.8
# ('pos', 0.8)
# I remember when Apple was the innovator, every one of those features is available on my Samsung 8. They should've just copied the infinity display too...would've made it look much nicer. pos 0.8
# ('neg', 1.0)
# This phone reminded me of the iphone 3gs, so glad that i got my S8+ for $775 neg 1.0
# ('pos', 1.0)
# techrax is gonna be so happy 😂😂😁 pos 1.0
# ('neg', 1.0)
# What if its night? Face recognition huh? neg 1.0
# ('neg', 1.0)
# The copy of the Samsung 8 neg 1.0
# ('neg', 1.0)
# how do you go from 8 to 10 neg 1.0
# ('neg', 1.0)
# Stealing not having a home button just like the Samsung galaxy s8 neg 1.0
# ('pos', 1.0)
# That's the 8 the iPhone x is different pos 1.0
# ('neg', 1.0)
# To me, it's just a waste of money. Samsung galaxy note 8 is better neg 1.0
# ('pos', 0.8)
# If Apple never named their iPhones with an s and numbered it like Air Jordan shoes every year, the iPhone X would have been released last year. Now after releasing 14 different iPhone models, it's confusing having an 8 and 10 but no 9.\n\nThis is what Apple should have done without s naming.. \n\n2007 - iPhone\n2008 - iPhone II instead of 3G\n2009 - iPhone III instead of 3Gs\n2010 - iPhone IV \n2011 - iPhone V instead of 4s\n2012 - iPhone VI instead of 5\n2013 - iPhone VII instead of 5s\n2014 - iPhone VIII instead of 6\n2015 - iPhone IX instead of 6s\n2016 - iPhone X instead of 7\n2017 - iPhone XI instead of 8 & X\n\nOnly the first iPhone and iPhone 4 were named properly. Poor iPhone 9 and 7 doesn't get an s model. Next year, remove the numerics and refer to it only as iPhone the same way the numerics no longer exist for iPads or a MacBook. pos 0.8
# ('pos', 0.8)
# If you look at the top you can see the camera they're using to film the iPhone is seeing the IR blasts coming from the sensor. pos 0.8
# ('neg', 0.8)
# No home button? *laughs in Android* neg 0.8
# ('neg', 1.0)
# just wait ... I'll sell my kidney n bay it .💔😂 neg 1.0
# ('neg', 1.0)
# #Apple have released another #Chinese clone it seems. Taking the last 3 years #tech already seen and throwing it into a device twice the price. I haven't seen any #groundbreaking moves from #Apple for many years now, even the computers are being #owned by competitors. neg 1.0
# ('pos', 1.0)
# xbox one x most powerfull console + iphone x= love pos 1.0
# ('neg', 1.0)
# The back is ugly neg 1.0
# ('neg', 1.0)
# Someone help me buy this phone. ... anyone?  Come on millionaires & billionaires can anyone help me neg 1.0
# ('neg', 1.0)
# It looks like a Samsung neg 1.0
# ('pos', 1.0)
# 5.8 inches X is larger the iPhone 8 is 5.5 inches ! The 8 has the button pos 1.0
# ('neg', 1.0)
# I Done! I'm going back to flip phones! Where can I buy a Motorola RAZR? neg 1.0
# ('neg', 1.0)
# Face recognition is the most stupid thing ever imo. I can get into my S5 just as fast, and with way more simplicity with my pattern lock. And is it just me or does that look like a past display screen, it's the complete opposite of an infinity screen and looks ugly. neg 1.0
# ('pos', 1.0)
# apple claims this is the first OLED screen which is good enough for the iPhone..... but it's a lesser screen to the S8 and G6.... and the claim is bullshit, the thing about this good enough stuff is about profit margins.... pos 1.0
# ('neg', 1.0)
# You guys are Giving more reasons to swich back to iphone. neg 1.0
# ('pos', 1.0)
# The phone looks cool on the front but the back and sides look awful, especially with that glass back and how the camera lip is like the Iphone 6 (Not smooth) and not like the Iphone 7 (smooth). pos 1.0
# ('neg', 1.0)
# Android has done this already not original neg 1.0
# ('neg', 1.0)
# Now without a charging port, you're still gonna buy it tho neg 1.0
# ('neg', 1.0)
# If I could only afford one... neg 1.0
# ('neg', 1.0)
# It looks like glass iPhone,,, that effect is not for me,,, 👎👎👎👎👎🍎 death neg 1.0
# ('neg', 1.0)
# Made in China for $1000 +? LOL,  I can only imagine if it was made in the U.S. Talk about high profit margin. Apple is such a SCAM! \nhttps://www.cnbc.com/2017/08/01/apple-earnings-q2-2017-how-much-cash-does-apple-have.html neg 1.0
# ('pos', 1.0)
# *Has features flagship Android phones have had for YEARS such as wireless charging, face unlock, etc. \n\n*Still, hilariously, convinces people that it's revolutionary and is worth over a $1,000\n\nApple - you are brilliant lol pos 1.0
# ('neg', 1.0)
# I wanted a better phone, if I wanted a camera I would have bought a Nikon. neg 1.0
# ('neg', 1.0)
# They should have put the fingerprint scanner on the apple logo on the back of the phone. neg 1.0
# ('neg', 1.0)
# Im gonna buy it just because im gonna get better snap chat filters smh 😤 neg 1.0
# ('neg', 1.0)
# Didn't the 7 just come out... neg 1.0
# ('neg', 1.0)
# wow tf copy samsung much 😂 neg 1.0
# ('pos', 1.0)
# Absolutely beautiful but wtf apple?! 1000 dollars??? Xpensive pos 1.0
# ('neg', 1.0)
# Tmobile JUMP neg 1.0
# ('neg', 0.8)
# *highkey copied on the Samsung 8..* neg 0.8
# ('neg', 1.0)
# Samsung is better neg 1.0
# ('neg', 1.0)
# iPhone Xpensive! neg 1.0
# ('neg', 1.0)
# Apple disabled the comments... Cowards neg 1.0
# ('neg', 1.0)
# what happened to iPhone 9???? neg 1.0
# ('neg', 1.0)
# DONT BUY IT neg 1.0
# ('neg', 1.0)
# wut happened with 9 neg 1.0
# ('neg', 1.0)
# they copied meizu haha neg 1.0
# ('pos', 1.0)
# no headphone jack? pos 1.0
# ('neg', 1.0)
# South Korea still wins. neg 1.0
# ('neg', 1.0)
# samsung galaxy 9 already copy this lol neg 1.0
# ('neg', 1.0)
# Battery? neg 1.0
# ('pos', 1.0)
# wtf 1000$ welp aint gettin this anytime soon im not rich pos 1.0
# ('neg', 1.0)
# What about 7s neg 1.0
# ('neg', 1.0)
# Did you mean: Samsung Galaxy S8 neg 1.0
# ('neg', 1.0)
# █▬█ █ ▀█▀  Apple Iphone X Amazing @@@ neg 1.0
# ('neg', 1.0)
# here is my review\n\n\n\n\noverpriced smartphone neg 1.0
# ('neg', 0.8)
# $1000....\n*Nope.* neg 0.8
# ('neg', 1.0)
# Copy s8 neg 1.0
# ('neg', 1.0)
# Rear looks shyt though neg 1.0
# ('neg', 0.6)
# Oooooh looks breakable good thang it's 800 dallars neg 0.6
# ('neg', 1.0)
# where is techrax neg 1.0
# ('neg', 1.0)
# Wtf happened to the iPhone 9? neg 1.0
# ('neg', 1.0)
# https://youtu.be/VASywEuqFd8 neg 1.0
# ('neg', 1.0)
# Waste of money... neg 1.0
# ('neg', 1.0)
# s8 knock off neg 1.0
# ('pos', 1.0)
# Did samsung make this? Nevermind that would be an insult to samsung and there amazing design team. Android has had these features for years, nothing new. Even the Samsung Galaxy s3 had the feature to unlock your phone with your face years ago. Nothing new invented here with Apple. pos 1.0
# ('neg', 1.0)
# Nothing's scarier than a guy replying to every comment with an advertisement for his channel. neg 1.0
# ('neg', 1.0)
# Wa da fuq? neg 1.0
# ('neg', 1.0)
# Jacksfilms = sarcasm comedian neg 1.0
# ('neg', 1.0)
# Idióta, iphone majmoló barmok!!!!!! neg 1.0
# ('neg', 0.6)
# Iphone x imbibing and review  https://youtu.be/mkZihjq3BF8 neg 0.6
# ('neg', 1.0)
# Congrats on getting this on Trending John. neg 1.0
# ('neg', 1.0)
# What happened to iphone 9? neg 1.0
# ('neg', 1.0)
# Ahahah lmao neg 1.0
# ('pos', 1.0)
# This is priceless pos 1.0
# ('neg', 1.0)
# #2 on trending neg 1.0
# ('neg', 1.0)
# gay emoji movie porn #YIAYfetish neg 1.0
# ('pos', 1.0)
# True true pos 1.0
# ('neg', 1.0)
# hiii neg 1.0
# ('neg', 1.0)
# 5TH ON TRENDING neg 1.0
# ('neg', 1.0)
# The 1000$ Emoji Machine\nOMFG the cringe neg 1.0
# ('neg', 1.0)
# Most disappointing Apple event ever neg 1.0
# ('neg', 0.8)
# Apple went full retard neg 0.8
# ('neg', 1.0)
# This guy is HILARIOUS! neg 1.0
# ('neg', 1.0)
# idiot neg 1.0
# ('neg', 1.0)
# There goes The spondsor neg 1.0
# ('neg', 1.0)
# Summed up perfectly neg 1.0
# ('pos', 1.0)
# Absolutely brilliant. You've outdone yourself Jack :) pos 1.0
# ('neg', 1.0)
# MAKE MORE PARODIES neg 1.0
# ('neg', 1.0)
# Animoji Movie, Coming 2018! neg 1.0
# ('neg', 0.8)
# This video was awesome lol neg 0.8
# ('neg', 1.0)
# Apple: The Emoji Machine now with fidget spinner emojis  (whispering) we being payed by Sony to advertise the fidget spinners movie (whispering)\nBy the way you forgot to include you can buy  at least 20 SNES minis. neg 1.0
# ('pos', 1.0)
# This is awesome. 1:20 XDDDDDDDDD pos 1.0
# ('neg', 1.0)
# A DEMENTOR LMAO neg 1.0
# ('neg', 1.0)
# Freakin 1000.00 cosplay simulator neg 1.0
# ('neg', 1.0)
# I've never been prouder, been a subber for like 3 years, and this video got on one of our newssites. neg 1.0
# ('neg', 1.0)
# THIS IS SO TRUE OMG 😂😂😂 neg 1.0
# ('neg', 1.0)
# iPhone X. We can't get the face unlock to work. You can't scroll up. And you can become a poop emoji.\nStarting at $999 neg 1.0
# ('neg', 1.0)
# the ceo is gay and his product is gay $hit. why do you cry so much? neg 1.0
# ('pos', 1.0)
# 👈 watch by clicking here you can see People's are entertaining pos 1.0
# ('pos', 0.8)
# *JACK LITERALLY  JUST COMMENTED ON MY LAST VIDEO* I'm crying right now 😭😭😭😢😢😢 pos 0.8
# ('neg', 1.0)
# How's it feel to be #5 on trending? neg 1.0
# ('neg', 1.0)
# Thank you for your life juice neg 1.0
# ('neg', 1.0)
# 4th video on trending is about all the great things about the apple x and 5th video on trending is this dissing it out like the crap it is neg 1.0
# ('pos', 1.0)
# Should have waited until the tenth iPhone to call it the X pos 1.0
# ('neg', 1.0)
# This video reminds me of my sister because I think of her in penguin costumes & clumsy. & She said similar things back in the day like with that webpage. neg 1.0
# ('neg', 1.0)
#  This is what Steve would have wanted.\n\n\n\n\n\nProbably. neg 1.0
# ('neg', 1.0)
# clickbait. i was expecting a parody, not the real thing reuploaded neg 1.0
# ('neg', 0.8)
# Yo Jack. This video was just shown on a news show in the netherlands!! So cool. You're great. neg 0.8
# ('neg', 1.0)
# Wuahaha it comes with 2 colors you cant and afford it 😂 neg 1.0
# ('neg', 1.0)
# I hope apple loses money cause after the iPhone 6'its all been shit neg 1.0
# ('neg', 1.0)
# JUST GOT BACK FROM 5TH GRADE CAMP neg 1.0
# ('neg', 1.0)
# You're only paying for the company Samsung is way better than Apple neg 1.0
# ('neg', 0.8)
# I honestly thought I was the only one and that was like are they serious it's official people only buy iPhones for the name iPhone because they don't have anything to offer it's nothing it's full of crap what I don't understand what the hell is that neg 0.8
# ('neg', 1.0)
# Who the fuck pays $1000 for an iPhone? neg 1.0
# ('neg', 1.0)
# Maybe this is just a marketing plot by HBO to get more people to watch GOT between seasons... neg 1.0
# ('pos', 1.0)
# Jack speaks the truth pos 1.0
# ('neg', 1.0)
# This is actually the original neg 1.0
# ('neg', 1.0)
# i'm a simple person, i see an Iphone video, i click neg 1.0
# ('neg', 1.0)
# thank you \n\n\n\n\n\ni hate apple and i was thinking of this kinda idea lol neg 1.0
# ('neg', 1.0)
# No more using your phone while charging neg 1.0
# ('pos', 1.0)
# That was pretty hilarious but also accurate that's why I stick with android because Apple is so damn expensive. pos 1.0
# ('pos', 1.0)
# Always intriguing to me to see how some people get so upset over other people's choice of phone. pos 1.0
# ('pos', 1.0)
# the best accurate description of  those apple products. :) pos 1.0
# ('neg', 1.0)
# So thanks apple now I'm confused did they just release the IPhone 8 and 10 at the same time making one obsolete also what's with these software companies and they're hatred of the number 9?!? neg 1.0
# ('neg', 1.0)
# Here in India an iPhone X 64 Gb will cost $1369.... neg 1.0
# ('neg', 1.0)
# Gaming pc that allows me to play games in 4k...or phone that allows me to watch games in 4k with a black bar...such a hard decision neg 1.0
# ('neg', 1.0)
# I really wanna get that emoji machine.. neg 1.0
# ('neg', 1.0)
# lol the dementor part, cracks me up. neg 1.0
# ('neg', 1.0)
# This is the quality content I subscribed for neg 1.0
# ('neg', 1.0)
# you said it wrong its: 3 switches and its 2 games neg 1.0
# ('neg', 1.0)
# Steve jobs vision was to sell stuff and make money not change the world. neg 1.0
# ('neg', 1.0)
# Pay $1,000 or $1,200 for the 256GB, and not even getting half the full screen experience of a galaxy S8 or S8+. With lower resolution, a notch that blocks your view, and no hard press home button. neg 1.0
# ('neg', 1.0)
# You know  you'll buy it. We'll all buy it. Damn you Apple! But seriously why buy an iPhone 8 when it's almost exactly like an iPhone 7 but slight with 2 more nucleus. Save money for iPhone X or better yet , save your money and in 2 more years the price will drop enough to buy it, after the new iPhone XI, XII, XII, XX come out. neg 1.0
# ('neg', 1.0)
# Do you know what really grinds my gears? The iPhone X in America costs $999, which should be about £760, but they still charge £999. neg 1.0
# ('pos', 1.0)
# Ever since Steve jobs passed away Iphone has gone to shit.  Iphones use to be sooo good. Like seriously wireless charging now? Samsung implemented it 2 generation ago with the S6 lmao xD pos 1.0
# ('neg', 0.8)
# u should get rid the parody neg 0.8
# ('neg', 1.0)
# man i wants this phone so bad but i can't afford it 😂😂 neg 1.0
# ('neg', 1.0)
# my local radio station played an audio clip from your video neg 1.0
# ('neg', 1.0)
# “I told Nintendo that Switch wouldn’t be a success before it went on sale because I thought that in the age of the smartphone no one would carry around a game console,”\n -Tsunekazu Ishihara neg 1.0
# ('neg', 0.6)
# they made it so easy for you hahaha emoji machine neg 0.6
# ('neg', 1.0)
# Where was the parody? neg 1.0
# ('pos', 1.0)
# ...
# ('neg', 1.0)
# Say- I gotta case of the swamp ass and it itches bad! neg 1.0
# ('neg', 1.0)
# Lol this guy is sick neg 1.0
# ('neg', 1.0)
# Please say Hey I'm Dan. I'm also Dan. Daaaaaaan. neg 1.0
# ('pos', 1.0)
# Do Guardians, that russian superhero movie! pos 1.0
# ('pos', 1.0)
# You were still too nice to them. pos 1.0
# ('pos', 0.8)
# I love these videos pos 0.8
# ('pos', 1.0)
# The best part of the movie was the credits pos 1.0
# ('neg', 1.0)
# i honestly don't get why people hate easter eggs so much. neg 1.0
# ('pos', 1.0)
# The amazing Spider-Man 2.  The universal monsters edition pos 1.0
# ('neg', 1.0)
# The movie was okay neg 1.0
# ('neg', 1.0)
# Honest trailer for The Room... oh hi Mark! neg 1.0
# ('neg', 1.0)
# quality of ur videos is getting bad by each new  honest trailer neg 1.0
# ('neg', 1.0)
# I liked the movie 🤷 neg 1.0
# ('neg', 1.0)
# Tom Cruise and Alex Kurtzman were the problems, Universal has 17 months to make adjustments and see what went right and what went wrong with The Mummy before Bride Of Frankenstein hits the big screen. neg 1.0
# ('neg', 1.0)
# CAN U PLS DO RICK AND MORTY ALREADY neg 1.0
# ('neg', 1.0)
# they made the mummy too hot.  I would let her kill me... neg 1.0
# ('neg', 1.0)
# Anyone else think that Tom Cruise would make a good Nathan Drake? neg 1.0
# ('neg', 1.0)
# I thought It was from warner brothers neg 1.0
# ('neg', 1.0)
# Tom Cruise runs from Sand (featuring the Mummy)...Haha...Lol neg 1.0
# ('neg', 1.0)
# DO THE ORIGINAL STEPHEN KING'S IT!!!!!!!!!!!!!! 🤣🤣🤣🤣😃😃😃😃 neg 1.0
# ('neg', 1.0)
# Say, Oh please, you're just a baggage handler. neg 1.0
# ('neg', 1.0)
# Hold the Fuvk up, Now Netflix is included neg 1.0
# ('neg', 1.0)
# So disappointing this movie was neg 1.0
# ('pos', 1.0)
# As someone who likes Brandon Fraser Mummy films, this remake had my spider sense going off from the beginning pos 1.0
# ('neg', 1.0)
# The second Russel Crowe went My name is Jekyll... Henry Jekyll! I quit. Screw this movie, the Dank Universe, the acting careers it ruined, and ESPECIALLY screw whatever they were planning on doing with Dracula. \n\n\n\nUnless Dracula Untold was supposed to be in this universe. Screw that movie, too. neg 1.0
# ('neg', 0.8)
# What I find odd is that they chose to use a clip from RKO's Hunchback of Notre Dame to represent the UNIVERSAL Monsters. neg 0.8
# ('neg', 1.0)
# Play say WORLD WAR TWO...\nGERMANY IS BACK...\nAND THIS TIME ITS PERSONAL neg 1.0
# ('neg', 0.6)
# Correction * tom cruise runs from sand AGAIN neg 0.6
# ('pos', 1.0)
# look Screen junkie , I love honest trailer,and I will continue loving it. but recent videos miss something that was done so well in the past:the pauses . I know that you have to keep track with the hype but quantity also require quality . Just,before joking , take a 2-3 seconds of silent ,ok? appreciate if you guys take time to read my comment pos 1.0
# ('pos', 1.0)
# Please do a Honest Trailer for GET OUT! That could be so funny with the movie's controversial topics. pos 1.0
# ('neg', 1.0)
# Please say...I can't think of anything for you to say actually. neg 1.0
# ('neg', 1.0)
# are you ever going to do unfriended been asking for years nowplease do unfriended soon neg 1.0
# ('pos', 1.0)
# Isn't it time for a Wonder Woman honest trailer? pos 1.0
# ('neg', 1.0)
# Look at ME! I'm THIRSTY!!! Lol neg 1.0
# ('pos', 1.0)
# i downloaded and saw The Mummy 2017  in the best quality guys. here's the Iink https://twitter.com/akewdiudri/status/907980087676477442\nyou must see too guys! that was awesome. pos 1.0
# ('pos', 1.0)
# Say, I was gonna read a good comment, but I chose yours instead pos 1.0
# ('neg', 1.0)
# This movie was bad.  I don't say that much neg 1.0
# ('neg', 1.0)
# Say what's up doc? neg 1.0
# ('neg', 1.0)
# now do the Brendan Fraser's Mummy!  please! neg 1.0
# ('neg', 1.0)
# Please say What would you do for a Klondike bar neg 1.0
# ('neg', 1.0)
# Your channel is throwing up 404 error saying this cant be found on this server, when ever I try to share it. neg 1.0
# ('neg', 0.8)
# Dude, it isn't a horror movie. neg 0.8
# ('neg', 1.0)
# Please do American Made. Decent movie👌🏽 neg 1.0
# ('neg', 1.0)
# Fun fact: This was actually second attempt to set up the Dark Universe... First one was Dracula Untold (Which was much better movie than Mummy IMO) neg 1.0
# ('pos', 0.8)
# This is why I love Honest Trailers, they are so savage. pos 0.8
# ('neg', 1.0)
# You should do the new movie IT next!! neg 1.0
# ('neg', 1.0)
# Why was this in my recommendations neg 1.0
# ('neg', 1.0)
# Can a remake of IT be considered original? neg 1.0
# ('neg', 1.0)
# Say How do you like dem apples 🍏 🍎 ? neg 1.0
# ('neg', 1.0)
# Say JON SNOW IS THE SONG OF ICE AND FIRE neg 1.0
# ('neg', 1.0)
# Eww sponsored by T-Mobile neg 1.0
# ('neg', 1.0)
# Tom Cruise rapes dead donkeys....just saying. neg 1.0
# ('neg', 1.0)
# do BABY DRIVER neg 1.0
# ('neg', 1.0)
# Do tremors neg 1.0
# ('neg', 1.0)
# Do It 2017!!!! neg 1.0
# ('neg', 1.0)
# Honest Trailer: Jem and the Holograms neg 1.0
# ('neg', 1.0)
# Alien 3 please! neg 1.0
# ('neg', 1.0)
# please say : ameterasu neg 1.0
# ('neg', 1.0)
# Say I'm Piiickleee Riiiiiick! neg 1.0
# ('neg', 1.0)
# Do Van Wilder neg 1.0
# ('neg', 1.0)
# do cars 3 neg 1.0
# ('neg', 1.0)
# Do Wonder woman! neg 1.0
# ('neg', 1.0)
# Reenact a star wars movie: say PEW PEW PEW VSSHH VSSHH PEW PEW PEW BOOM neg 1.0
# ('neg', 1.0)
# Please say : omae wa mo shindeiru neg 1.0
# ('pos', 1.0)
# Please say uncle touchy. Prease honest trailer man prease!!! pos 1.0
# ('neg', 1.0)
# Thank you. neg 1.0
# ('neg', 1.0)
# Great Review neg 1.0
# ('neg', 1.0)
# wait, tmobile gives out free netflix? neg 1.0
# ('neg', 1.0)
# STOP IT! neg 1.0
# ('neg', 1.0)
# Do Baby Driver!!!! neg 1.0
# ('neg', 1.0)
# Do It!!!!!!! neg 1.0
# ('pos', 1.0)
# Need wonderwoman honest trailer😓 pos 1.0
# ('neg', 1.0)
# Ooh, can you guys do Lifeforce (1985)?! neg 1.0
# ('neg', 1.0)
# Please do the Brandon Fraiser Mummy neg 1.0
# ('neg', 1.0)
# holyshit, Tom Cruise is older than Russel Crowe! neg 1.0
# ('neg', 1.0)
# Plz say Scooby-Dooby-Dooooooooooooooooooooooooooooooooooooooooooooooooooo! neg 1.0
# ('neg', 1.0)
# https://www.youtube.com/edit?o=U&video_id=1kiaU5q5mSc neg 1.0
# ('neg', 1.0)
# Lmao they actually uploaded that trailer?? neg 1.0
# ('neg', 1.0)
# Powers to suck you dry xD neg 1.0
# ('neg', 1.0)
# suck you dry 😂😂 neg 1.0
# ('neg', 1.0)
# The Dummy neg 1.0
# ('neg', 1.0)
# Say JFK did 911 neg 1.0
# ('neg', 1.0)
# Do IT(1990) neg 1.0
# ('neg', 1.0)
# Do Get Out! neg 1.0
# ('neg', 1.0)
# Welcome to Wage Slavery! neg 1.0
# ('pos', 1.0)
# Raph was every 40 year old part time, non-degreed student who still refers to freshmen girls as fresh meat. pos 1.0
# ('neg', 0.6)
# So I used to live right in front of the tour room aka mint condition room. Anyway, the thing is many many parents take a an opportunity to peek and even take pictures of our room when clearly someone is in the room!  Please don't open or peak into other people's room! or even try to open closed room! It is common for us to leave our doors slightly open for other dormmates to come by and say hi to hang out! We don't mind if you are in the hallway, but if you push the door like a creep and take a picture? We have a problem. Also, we know for sure that the tour guys have warned to not open our doors or peak inside because they know 1/50 parents do this and out of many tour guys are our own dormmates. neg 0.6
# ('neg', 1.0)
# Collegehumor remembered their name and made a video about college humor...? It's been too long. neg 1.0
# ('neg', 1.0)
# Honestly I'm three weeks into college and i want to kill myself. neg 1.0
# ('neg', 1.0)
# So you don't have the one kid who is terrified of the  prospect of his impending future and how much his decisions actually mean despite having 18 years of where he was basically along for the ride and constantly thinks about putting a barrel to their head?… neg 1.0
# ('neg', 1.0)
# im watching this at college neg 1.0
# ('neg', 1.0)
# I got accepted into hardboard with an IQ of 43 at the age of 45 neg 1.0
# ('neg', 1.0)
# That last bit with the questions is literally me every time I am in class... neg 1.0
# ('pos', 0.6)
# What about the construction of buildings that actually sound cool, but will never be completed until after you finish college. pos 0.6
# ('neg', 1.0)
# The loud, yelly dude in the blue shirt... so spot on. Every day, I just want to kick all of those guys right in the nuts... neg 1.0
# ('neg', 1.0)
# she was so cute omg throw this in the garbage xD 🤣🤣❤❤ neg 1.0
# ('neg', 1.0)
# Forgot to mention the blue lighting system neg 1.0
# ('neg', 1.0)
# I'm so glad I'm an old fart who never has to go to school again. Woo Hoo! neg 1.0
# ('neg', 1.0)
# At last some actual College Humor. neg 1.0
# ('pos', 1.0)
# Yo this was funny af pos 1.0
# ('neg', 1.0)
# Holy shit, a college joke on college humor. It's been a while. neg 1.0
# ('neg', 1.0)
# The Amazon prime student membership is just gold neg 1.0
# ('neg', 1.0)
# I went to Boston University.  When I would have my spring break, I would pretend to be a Harvard student and go to their classes.  Harvard was fun.  Their lectures were more interesting than ours, which was totally unfair.  I even gave someone else directions one time.  MIT was depressing/suffocating though.  It was a combination of the people and atmosphere.  I only pretended to go there for half a day. neg 1.0
# ('neg', 1.0)
# Is it just me or is Rekha really cute? neg 1.0
# ('neg', 1.0)
# That was an ad neg 1.0
# ('neg', 1.0)
# But for real, why is it that all the science buildings are hideous? neg 1.0
# ('neg', 1.0)
# You forgot to mention that college is a complete waste of time and money for a lot of people. neg 1.0
# ('neg', 1.0)
# Thank you from tour guides everywhere. Go buckeyes neg 1.0
# ('neg', 1.0)
# Wow this collegehumor video is actually pretty good. And it's even about college neg 1.0
# ('neg', 1.0)
# Was that UCLA? It looks super-familier... neg 1.0
# ('neg', 1.0)
# Holy shit... is it a collegehumor video about... college??? neg 1.0
# ('neg', 1.0)
# Hey, it's actual college-based humor! neg 1.0
# ('neg', 1.0)
# Seems like College Season is starting. Anyway...dropout rate is so high. neg 1.0
# ('pos', 0.6)
# well this is so true i have cancer now pos 0.6
# ('pos', 1.0)
# This is so true 😂 pos 1.0
# ('neg', 1.0)
# They should make a more violent version of this video where the statue is a random black guy neg 1.0
# ('pos', 1.0)
# Yeah... \nEveryone, please watch my tiny nature videos. There is no talking in them. Shhh! pos 1.0
# ('neg', 1.0)
# I was soooo that Dad when I took my daughter to my old university.  Lolz!!! neg 1.0
# ('neg', 1.0)
# Oh shit an actual college humor video! neg 1.0
# ('pos', 1.0)
# Don't forget paying hundreds of dollars for a parking permit and not being able to find parking 🤦🏽‍♀️ pos 1.0
# ('neg', 1.0)
# The Indian girl is hot. neg 1.0
# ('neg', 1.0)
# Lmao I just went on a college tour the other day this was pretty spot on especially the walking backwards jokes and the students passing by going WOOOOO or THIS PLACE IS GREAT COME HERE neg 1.0
# ('neg', 1.0)
# this is so true on so many levels that it kinda hurts neg 1.0
# ('neg', 1.0)
# The Asian dad was classic lolol neg 1.0
# ('neg', 1.0)
# This video is sooo racist why is the black guy the only one that needs attention that is a stupid stereo type support your local antifa neg 1.0
# ('neg', 1.0)
# I love idolizing football or basketball teams, and would gladly sell my soul in support.  Would I make it at a University like this? neg 1.0
# ('pos', 0.6)
# I...Don't think I could go to college.\nIt would not end well. pos 0.6
# ('pos', 1.0)
# At they're being honest here pos 1.0
# ('neg', 1.0)
# when you tour a school founded by Oliver Cromwell :O neg 1.0
# ('pos', 1.0)
# I heard Evergreen offers the best Gender Studies and Liberal Arts programs for today's youth. pos 1.0
# ('pos', 0.6)
# We would like to teach you some of our schools special traditions *sweet Caroline begins to play* pos 0.6
# ('neg', 1.0)
# After so long finally an honest video the gods have answered my prayers neg 1.0
# ('pos', 1.0)
# katie's hair is amazing pos 1.0
# ('pos', 1.0)
# Why does this kind of remind me of honest movie trailers? pos 1.0
# ('neg', 1.0)
# C O L L E G E U N I V E R S I T Y neg 1.0
# ('neg', 1.0)
# Can you guys do Honest day at school? Please like this so they can see neg 1.0
# ('neg', 0.8)
# Well damn. So its basically when you get introduced to the career center neg 0.8
# ('neg', 1.0)
# WHY DID YOU MAKE FURRY FORCE?! SO NASTY!!! neg 1.0
# ('neg', 1.0)
# It's a liberal arts school Sweetie , get your ass in the car ! neg 1.0
# ('neg', 1.0)
# College humour makes a video about college! neg 1.0
# ('neg', 1.0)
# Im a great comedian that has gotten millions of views and thought about suicide i was thinking about drowning myself so many times if you all wanna save me please DM me on instagram @comedian_thefreshman they all say I might be better than Kevin Hart neg 1.0
# ('neg', 1.0)
# Honest college tour on your right you'll see the place where everyone submits there fake rape accusations slips and and the left you'll see see a bunch of fat disgusting useless borderline retarded sjw's oh god run I'm a straight white male that just looked at them I can already hear them typing typing im a neo nazi fascist+rapist looks straight ahead and now you can see Antica members destroying trash cans because they wasted there time in gender studies now leave me with your children so I can destroy there minds with ridiculous thoughts and then basically tell the white ones to become slaves I would say something about straight people but I'm too afraid that even men...... oh shit yep I just got stabbed and beaten with a bike lock \n\nThank you for reading the proper script for this skit neg 1.0
# ('neg', 1.0)
# I'm applying this year, this hits close. neg 1.0
# ('pos', 0.6)
# A college humor sketch revolving around college and containing some form of humor, it's a belated Labor Day miracle. pos 0.6
# ('neg', 1.0)
# So...Cracked basically did the same thing recently JS neg 1.0
# ('neg', 1.0)
# It's been a long time CollegeHumor did a video with college humor in it. neg 1.0
# ('neg', 1.0)
# THIS IS SO ACCURATE neg 1.0
# ('neg', 1.0)
# Get out of my head!!!! neg 1.0
# ('neg', 1.0)
# its ironically sad how these humor videos do a better job at reaffirming my dislike of literally everything, than they do in making me actually laugh :- neg 1.0
# ('neg', 1.0)
# Constantly pointing out your jokes isn't funny😞 neg 1.0
# ('neg', 1.0)
# The accuracy hurts neg 1.0
# ('pos', 1.0)
# This is terrifyingly accurate pos 1.0
# ('neg', 1.0)
# Why is this trending neg 1.0
# ('neg', 1.0)
# Is this... UCLA? neg 1.0
# ('neg', 1.0)
# College University neg 1.0
# ('neg', 1.0)
# So. Fucking. True. neg 1.0
# ('pos', 1.0)
# Omg this is fucking hilarious. pos 1.0
# ('pos', 1.0)
# so funny, so true pos 1.0
# ('neg', 1.0)
# That's UCLA lol neg 1.0
# ('neg', 1.0)
# ayyyyy fellow Bruins where u at? neg 1.0
# ('pos', 1.0)
# lol brilliant pos 1.0
# ('pos', 1.0)
# Very accurate video pos 1.0
# ('neg', 1.0)
# Whooooo! neg 1.0
# ('neg', 1.0)
# Great Job Guys 😂 Loved it neg 1.0
# ('neg', 1.0)
# Spot on neg 1.0
# ('neg', 1.0)
# haha this is depressing haha! neg 1.0
# ('neg', 0.6)
# AIB did this first. neg 0.6
# ('neg', 0.8)
# *polite laughter* neg 0.8
# ('pos', 1.0)
# Britanick have gotten pudgier and more gender diverse lately. pos 1.0
# ('pos', 0.6)
# Gotta get that sponsorship money eh ch? Lol pos 0.6
# ('pos', 1.0)
# Most accurate video ever lol pos 1.0
# ('neg', 1.0)
# Welcome to college collge humir neg 1.0
# ('neg', 1.0)
# Raf is so cute. neg 1.0
# ('pos', 1.0)
# Plz make funny videos again🙏🏼 pos 1.0
# ('neg', 1.0)
# Garbage neg 1.0
# ('neg', 1.0)
# Copied AIB neg 1.0
# ('pos', 1.0)
# College Humour is amazing! pos 1.0
# ('neg', 1.0)
# WOO look at me! neg 1.0
# ('neg', 1.0)
# [polite laughter] neg 1.0
# ('neg', 1.0)
# lol😂😂😂 neg 1.0
# ('neg', 1.0)
# Generic attention comment neg 1.0
# ('pos', 1.0)
# Zero amount of funny pos 1.0
# ('neg', 1.0)
# Honest? I see no random color hairgender studies or lesbian dance theory activist or 98% white blm crowd or snowflakes running from safe space to safe space scared they might run into a FACT.   lets see the real version...... neg 1.0
# ('neg', 1.0)
# What, no joke about how you can't apply if you are going to call a woman a woman, because that is offensive to those who sexually identify as Attack Helicopters, trapped in a womans body? neg 1.0
# ('neg', 1.0)
# Floyd Mayweather, the swimmer. neg 1.0

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style
import time

style.use('ggplot')

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

def animate():
    graph_data = open('youtube-out.txt','r').read()
    lines = graph_data.split('\n')
    
    xar = []
    yar = []
    x = 0
    y = 0
    
    for l in lines:
        x += 1
        if 'pos' in l:
            y += 1
        elif 'neg' in l:
            y -= 1
        xar.append(x)
        yar.append(y)
    ax1.clear()
    ax1.plot(xar, yar)
    
ani = animation.FuncAnimation(fig, animate(), interval=1000)
plt.show()

# %% [markdown]
# ## Using TextBlob

# %%
from textblob import TextBlob
comments = pd.read_csv('UScomments.csv',encoding='utf8',error_bad_lines=False)[:1000]

def pol(text):
    a=str(text)
    b=TextBlob(a)
    return b.sentiment.polarity

comments['polarity'] = comments.comment_text.apply(pol)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-d133509b43c0> in <module>
#       1 from textblob import TextBlob
# ----> 2 comments = pd.read_csv('UScomments.csv',encoding='utf8',error_bad_lines=False)[:1000]
#       3
#       4 def pol(text):
#       5     a=str(text)
#
# NameError: name 'pd' is not defined

# %%
def checker(text):
    if text>0:
        return 1
    elif text<0:
        return -1
    else:
        return 0

comments['polarity'] = comments['polarity'].apply(checker)
comments.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-3aea7c335854> in <module>
#       7         return 0
#       8
# ----> 9 comments['polarity'] = comments['polarity'].apply(checker)
#      10 comments.head()
#
# NameError: name 'comments' is not defined

# %%
import seaborn as sns

sns.set_style('whitegrid')
sns.countplot(x='polarity',data=comments)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-da1d8a81d8f0> in <module>
#       2
#       3 sns.set_style('whitegrid')
# ----> 4 sns.countplot(x='polarity',data=comments)
#
# NameError: name 'comments' is not defined

# %%
style.use('ggplot')

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

def animate():
    xar = []
    yar = []
    x = 0
    y = 0
    
    for l in comments['polarity']:
        x += 1
        if l == 1:
            y += 1
        elif l == -1:
            y -= 1
        xar.append(x)
        yar.append(y)
    ax1.clear()
    ax1.plot(xar, yar)
    
ani = animation.FuncAnimation(fig, animate(), interval=1000)
plt.show()
